# %%
import os
import sys
import math
import pandas as pd
import json
import numpy as np
file_path1 = '/home/SENSETIME/gaoyuhui/ws/pilotmdc_rscl/senseauto-pilot-decision/common_math/athena/build'
sys.path.append(file_path1)
print(file_path1)
import pybind_dlp
def read_json_file(json_file):
    map_data = None
    try:
        with open(json_file, 'r', encoding='utf-8') as file:
            map_data = json.load(file)
    except Exception as e:
        print(f"read map data failed")

    return map_data
# Out:
# /home/SENSETIME/gaoyuhui/ws/pilotmdc_rscl/senseauto-pilot-decision/common_math/athena/build

# %%
# read map info
file_path = '/home/SENSETIME/gaoyuhui/ws/pilotmdc_rscl/senseauto-pilot-decision/common_math/athena/\
dlp_model_evaluation/test_data2/ce3d12adec1fdf713f4504f54b4aeb98f6a59781456dc8a0203a017104458238/\
log_map_archive_ce3d12adec1fdf713f4504f54b4aeb98f6a59781456dc8a0203a017104458238.json'
map_data = read_json_file(file_path)
print(map_data)
# Out:
# {'drivable_areas': {'1': {'id': 1, 'area_boundary': []}, '2': {'id': 2, 'area_boundary': []}, '3': {'id': 3, 'area_boundary': []}, '4': {'id': 4, 'area_boundary': []}, '5': {'id': 5, 'area_boundary': []}, '6': {'id': 6, 'area_boundary': []}, '7': {'id': 7, 'area_boundary': []}, '8': {'id': 8, 'area_boundary': []}, '9': {'id': 9, 'area_boundary': []}, '10': {'id': 10, 'area_boundary': []}, '11': {'id': 11, 'area_boundary': []}, '12': {'id': 12, 'area_boundary': []}}, 'lane_segments': {'1': {'centerline': [{'x': -966.1835534039815, 'y': 1655.9130462092592, 'z': 0.35460998479243244}, {'x': -965.9592844112532, 'y': 1655.9185674406544, 'z': 0.3533203920411552}, {'x': -965.7350154185249, 'y': 1655.9240886720497, 'z': 0.3520307992898779}, {'x': -965.2726459625782, 'y': 1655.9362776613489, 'z': 0.3491441604127772}, {'x': -964.8102765066313, 'y': 1655.9484666506485, 'z': 0.3462575215357049}, {'x': -964.3479070506844, 'y': 1655.9606556399474, 'z': 0.34337088265860416}, {'x': -963.8855375947376
# ...

# %%
occ_vector = pybind_dlp.OccVectorGenerator()
occ_data = pybind_dlp.RawOccInfo()
occ_data.x_partition.num_partition = map_data['occ_data']['xPartition_info']['numPartition']
occ_data.x_partition.ranges = map_data['occ_data']['xPartition_info']['ranges']
occ_data.x_partition.steps = map_data['occ_data']['xPartition_info']['steps']
occ_data.x_partition.num_voxels_per_range = map_data['occ_data']['xPartition_info']['numVoxelsPerRange']
print(occ_data.x_partition)

occ_data.y_partition.num_partition = map_data['occ_data']['yPartition_info']['numPartition']
occ_data.y_partition.ranges = map_data['occ_data']['yPartition_info']['ranges']
occ_data.y_partition.steps = map_data['occ_data']['yPartition_info']['steps']
occ_data.y_partition.num_voxels_per_range = map_data['occ_data']['yPartition_info']['numVoxelsPerRange']
print(occ_data.y_partition)

occ_mgr_voxels = []
for occ_raw_feature in map_data['occ_data']['occ_info']:
    if occ_raw_feature['type'] == 2:
        voxel = pybind_dlp.OccVoxel()
        voxel.i = occ_raw_feature['index'][0]
        voxel.j = occ_raw_feature['index'][1]
        voxel.v = occ_raw_feature['type']
        occ_mgr_voxels.append(voxel)
occ_data.voxel_list = occ_mgr_voxels
print(occ_data.voxel_list)
# Out:
# ...
# [<pybind_dlp.OccVoxel object at 0x7f4867e07270>, <pybind_dlp.OccVoxel object at 0x7f4867e07430>, <pybind_dlp.OccVoxel object at 0x7f4867e07470>, <pybind_dlp.OccVoxel object at 0x7f4867e074b0>, <pybind_dlp.OccVoxel object at 0x7f4867e074f0>, <pybind_dlp.OccVoxel object at 0x7f4867e07530>, <pybind_dlp.OccVoxel object at 0x7f4867e07570>, <pybind_dlp.OccVoxel object at 0x7f4867e075b0>, <pybind_dlp.OccVoxel object at 0x7f4867e075f0>, <pybind_dlp.OccVoxel object at 0x7f4867e07630>, <pybind_dlp.OccVoxel object at 0x7f4867e07670>, <pybind_dlp.OccVoxel object at 0x7f4867e076b0>, <pybind_dlp.OccVoxel object at 0x7f4867e076f0>, <pybind_dlp.OccVoxel object at 0x7f4867e07730>, <pybind_dlp.OccVoxel object at 0x7f4867e07770>, <pybind_dlp.OccVoxel object at 0x7f4867e077b0>, <pybind_dlp.OccVoxel object at 0x7f4867e077f0>, <pybind_dlp.OccVoxel object at 0x7f4867e07830>, <pybind_dlp.OccVoxel object at 0x7f4867e07870>, <pybind_dlp.OccVoxel object at 0x7f4867e078b0>, <pybind_dlp.OccVoxel object at 0x7f48
# ...

# %%
xPartition_info = map_data['occ_data']['xPartition_info']

length = 0
for i in xPartition_info['numVoxelsPerRange']:
    length += i
length

yPartition_info = map_data['occ_data']['yPartition_info']
# yPartition_info

width = 0
for i in yPartition_info['numVoxelsPerRange']:
    width += i
width

image = np.zeros((length, width))

count = 0
for v in map_data['occ_data']['occ_info']:
    x = v['index'][0]
    y = v['index'][1]
    # print(x, y, v['type'])
    if v['type'] == 2:
        image[x, y] = 2
        count+=1
        # print(x, y)
    elif v['type'] == 1:
        image[x, y] = 1

ego_x = 0
ego_y = width // 2


print(count)
for i in range(length):
    for j in range(width):
        print(i, j, image[i, j])
# Out:
# 1280
# 0 0 0.0
# 0 1 0.0
# 0 2 0.0
# 0 3 0.0
# 0 4 0.0
# 0 5 0.0
# 0 6 0.0
# 0 7 0.0
# 0 8 0.0
# 0 9 0.0
# 0 10 0.0
# 0 11 0.0
# 0 12 0.0
# 0 13 0.0
# 0 14 0.0
# 0 15 0.0
# 0 16 0.0
# 0 17 0.0
# 0 18 0.0
# 0 19 0.0
# 0 20 0.0
# 0 21 0.0
# 0 22 0.0
# 0 23 0.0
# 0 24 0.0
# 0 25 0.0
# 0 26 0.0
# 0 27 0.0
# 0 28 0.0
# 0 29 0.0
# 0 30 0.0
# 0 31 0.0
# 0 32 0.0
# 0 33 0.0
# 0 34 0.0
# 0 35 0.0
# 0 36 0.0
# 0 37 0.0
# 0 38 0.0
# 0 39 0.0
# 0 40 0.0
# 0 41 1.0
# 0 42 0.0
# 0 43 0.0
# 0 44 2.0
# 0 45 2.0
# 0 46 2.0
# 0 47 1.0
# 0 48 1.0
# 0 49 1.0
# 0 50 1.0
# 0 51 1.0
# 0 52 1.0
# 0 53 1.0
# 0 54 1.0
# 0 55 1.0
# 0 56 1.0
# 0 57 1.0
# 0 58 1.0
# 0 59 1.0
# 0 60 1.0
# 0 61 1.0
# 0 62 1.0
# 0 63 1.0
# 0 64 1.0
# 0 65 1.0
# 0 66 1.0
# 0 67 1.0
# 0 68 1.0
# 0 69 1.0
# 0 70 1.0
# 0 71 2.0
# 0 72 2.0
# 0 73 1.0
# 0 74 1.0
# 0 75 1.0
# 0 76 1.0
# 0 77 1.0
# 0 78 1.0
# 0 79 1.0
# 0 80 1.0
# 0 81 1.0
# 0 82 1.0
# 0 83 1.0
# 0 84 1.0
# 0 85 1.0
# 0 86 1.0
# 0 87 1.0
# 0 88 1.0
# 0 89 1.0
# 0 90 1.0
# ...

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

p = figure(width=400, height=600, x_range=(width, 0), y_range=(0, length))

x_1 = []
y_1 = []
x_2 = []
y_2 = []
for i in range(length):
    for j in range(width):
        # print(i, j, image[i][j])
        if image[i][j] == 1:
            x_1.append(i)
            y_1.append(j)
        elif image[i][j] == 2:
            x_2.append(i)
            y_2.append(j)

p.scatter(y_1, x_1, color='green', size=1, alpha=1, legend_label = '地面')
p.scatter(y_2, x_2, color='red', size=3, alpha=0.3, legend_label = '其他')
p.scatter(ego_y, ego_x, color='blue', size=10, legend_label = 'ego')

occ_raw_data = map_data['occ_data']
occ_mgr = pybind_dlp.OccVectorGenerator()
occ_mgr_raw_info = pybind_dlp.RawOccInfo()
occ_mgr_raw_info.x_partition.num_partition = occ_raw_data['xPartition_info']['numPartition']
occ_mgr_raw_info.x_partition.ranges = occ_raw_data['xPartition_info']['ranges']
occ_mgr_raw_info.x_partition.steps = occ_raw_data['xPartition_info']['steps']
occ_mgr_raw_info.x_partition.num_voxels_per_range = occ_raw_data['xPartition_info']['numVoxelsPerRange']

occ_mgr_raw_info.y_partition.num_partition = occ_raw_data['yPartition_info']['numPartition']
occ_mgr_raw_info.y_partition.ranges = occ_raw_data['yPartition_info']['ranges']
occ_mgr_raw_info.y_partition.steps = occ_raw_data['yPartition_info']['steps']
occ_mgr_raw_info.y_partition.num_voxels_per_range = occ_raw_data['yPartition_info']['numVoxelsPerRange']

x_step = occ_mgr_raw_info.x_partition.steps
y_step = occ_mgr_raw_info.y_partition.steps
x_sum = occ_mgr_raw_info.x_partition.num_voxels_per_range[0]
y_sum = occ_mgr_raw_info.y_partition.num_voxels_per_range[0]
y_mid = y_sum // 2

# ego_x_vec = x_step * np.array([math.cos(ego_head.iloc[0]), math.sin(ego_head.iloc[0])])
# ego_y_vec = y_step * np.array([-math.sin(ego_head.iloc[0]), math.cos(ego_head.iloc[0])])
occ_mgr_voxels = []
for occ_raw_feature in occ_raw_data['occ_info']:
    if occ_raw_feature['type'] == 2:
        voxel = pybind_dlp.OccVoxel()
        voxel.i = occ_raw_feature['index'][0]
        voxel.j = occ_raw_feature['index'][1]
        voxel.v = occ_raw_feature['type']
        occ_mgr_voxels.append(voxel)
occ_mgr_raw_info.voxel_list = occ_mgr_voxels

res = occ_mgr.build_occ_vector(occ_mgr_raw_info)
res_x = []
res_y = []
for item in res:
    for pt in item.free_space_edge:
        res_x.append(pt[0])
        res_y.append(pt[1])
p.scatter(res_y, res_x, color='black', size=3, alpha=3, legend_label = 'ans')
# 在notebook中显示图像
output_notebook()
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="db3c064f-85e2-4eff-9131-61c278ae32c2">Loading BokehJS ...</span>
#     </div>
#   <div id="d671feb3-d15e-4ff9-9297-aa61769dcb0a" data-root-id="p1627" style="display: contents;"></div>

# %%
ego_x = -882.6985635195764
ego_y = 1655.090100118679
ego_theta = 0.03295222
def transform(x0, y0, theta0, x_prime, y_prime, theta_prime):
    cos_theta0 = math.cos(theta0)
    sin_theta0 = math.sin(theta0)
    x = x0 + (x_prime * cos_theta0) - (y_prime * sin_theta0)
    y = y0 + (x_prime * sin_theta0) +  (y_prime * cos_theta0)
    theta = theta0 + theta_prime
    return x, y, theta
x_local = []
y_local = []
for item in res:
    for pt in item.free_space_edge:
        pt_local = transform(ego_x, ego_y, ego_theta, pt[0], (pt[1] - 60), 0)
        x_local.append(pt_local[0])
        y_local.append(pt_local[1])
plot = figure(width=400, height=600, match_aspect = True)    
plot.scatter(x_local, y_local, color='black', size=3, alpha=3, legend_label = 'ans')
plot.scatter(ego_x, ego_y, color='blue', size=10, legend_label = 'ego')
output_notebook()
show(plot)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c45fe597-79a6-42be-aba6-cdef4b7d18f4">Loading BokehJS ...</span>
#     </div>
#   <div id="e1210659-100d-4de9-9357-2072f82cb5f1" data-root-id="p2020" style="display: contents;"></div>

# %%
class Point2D:
    def __init__(self, x=0.0, y=0.0):
        self.x = x
        self.y = y

class Segment:
    def __init__(self, start=None, end=None):
        self.start = start if start else Point2D()
        self.end = end if end else Point2D()

    def __repr__(self):
        return f"Segment(start=({self.start.x}, {self.start.y}), end=({self.end.x}, {self.end.y}))"
def intersects(seg1, seg2):
    # rapid_rejection 快速排斥法
    if (max(seg1.start.x, seg1.end.x) < min(seg2.start.x, seg2.end.x) or
        max(seg1.start.y, seg1.end.y) < min(seg2.start.y, seg2.end.y) or
        max(seg2.start.x, seg2.end.x) < min(seg1.start.x, seg1.end.x) or
        max(seg2.start.y, seg2.end.y) < min(seg1.start.y, seg1.end.y)):
        return False

    # cross 叉积法
    def cross_product(p1, p2, p3):
        return (p2.x - p1.x) * (p3.y - p1.y) - (p2.y - p1.y) * (p3.x - p1.x)

    # 判断线段的两个端点是否在另一条线段的两侧
    if (cross_product(seg2.start, seg2.end, seg1.start) * cross_product(seg2.start, seg2.end, seg1.end) > 0 or
        cross_product(seg1.start, seg1.end, seg2.start) * cross_product(seg1.start, seg1.end, seg2.end) > 0):
        return False

    return True

# 示例
seg1 = Segment(Point2D(1, 1), Point2D(4, 1))
seg2 = Segment(Point2D(1, 4), Point2D(4, 4))

if intersects(seg1, seg2):
    print("线段相交")
else:
    print("线段不相交")
# Out:
# 线段不相交

# %%
ego_origin_state_theta = 0.78
ego_origin_state_x = 1
ego_origin_state_y = 1
pt = Point2D(1.4, 0)

ego_vec = Point2D(math.cos(ego_origin_state_theta), math.sin(ego_origin_state_theta))
query_pt_vec = Point2D((pt.x - ego_origin_state_x),(pt.y - ego_origin_state_y))
dot_product = ego_vec.x * query_pt_vec.x + ego_vec.y * query_pt_vec.y
dot_product
# Out:
# -0.4189140039954993
