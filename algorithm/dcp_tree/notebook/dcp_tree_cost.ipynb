# %%
import sys
import numpy as np
import os
current_directory = os.getcwd()
relative_path1 = '../../build/env_simulator'
relative_path2 = '../../build/cilqr'
file_path1 = os.path.join(current_directory, relative_path1)
file_path2 = os.path.join(current_directory, relative_path2)
sys.path.append(file_path1)
sys.path.append(file_path2)
import pybind_env_simulator
relative_path3 = '../../env_simulator'
file_path3 = os.path.join(current_directory, relative_path3)
sys.path.append(file_path3)
relative_path4 = '../'
file_path4 = os.path.join(current_directory, relative_path4)
sys.path.append(file_path4)
relative_path5 = '../../build/dcp_tree'
file_path4 = os.path.join(current_directory, relative_path5)
sys.path.append(relative_path5)
relative_path6 = '../python_plot'
relative_path6 = os.path.join(current_directory, relative_path6)
sys.path.append(relative_path6)
import pybind_ilqr
import pybind_dcp_tree
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import WheelZoomTool
import json
from pprint import pprint
from collections import defaultdict
import itertools
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import LabelSet, ColumnDataSource
from python_plot import dcp_tree_plot
from bokeh.layouts import column, row
file_path = '/home/SENSETIME/chengren1/ws/gitlab.senseauto.com/common_math/algorithm/dcp_tree/data/'

# %% [markdown]
# # f_19

# %%
file_name = 'f_19.json'
file = file_path + file_name
dcp_tree = pybind_dcp_tree.DCPTree()
root_node = pybind_dcp_tree.DCPTreeNodeData()
ego_info = pybind_ilqr.IDMCarInfo(0.0, 17.050079695847774, 0.37265267968177795, 4.886)
root_node.obs_pos = dcp_tree_plot.read_json(file)
root_node.ego_pos = ego_info
dcp_tree.set_IDM_params(1.0, 3, 17.050079695847774, 27)
root_node.tree_trace.clear()
dcp_tree.update_tree(root_node)
dcp_tree.show()
all_paths = dcp_tree.get_all_path()
print("all paths size is: ")
print(len(all_paths))
sorted_paths = sorted(all_paths, key=lambda x: x[-1][0])
top_10_min_cost_paths = sorted_paths[:15]
for i, path in enumerate(top_10_min_cost_paths):
#     print(f"Path {i+1} with last step cost {path[-1][0]}:")
    print("Path {} with last step cost {:.1f}:".format(i+1, path[-1][0]))
    for step in path:
#         print(f"  Time: {step[1]}, Action: {step[2]}, Cost: {step[0]}")
        print("  Time: {}, Action: {}, Cost: {:.1f}, CostLC: {:.1f}, CostS: {:.1f}, CostV: {:.1f}, S: {:.1f}, V: {:.1f}, A: {:.1f}". \
                      format(step[1], step[2], step[0], \
                             step[3].cost_lc, \
                            step[3].cost_s, \
                            step[3].cost_v,
                            step[3].s,
                            step[3].v,
                            step[3].a))
    print()
sequences = dcp_tree_plot.converted_sequences(top_10_min_cost_paths)
# pprint(sequences)
plot = dcp_tree_plot.plot_dcp_tree_node(sequences)
output_notebook()
p = dcp_tree_plot.plot_lane_and_objs(root_node.obs_pos, ego_info)
show(column(p, plot))
# Out:
# all paths size is:
# 15
# Path 1 with last step cost -49.2:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0, CostLC: 0.0, CostS: 0.0, CostV: 0.0, S: 0.0, V: 0.0, A: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: -19.5, CostLC: 0.0, CostS: -2.0, CostV: -17.5, S: 17.3, V: 17.5, A: 0.4
#   Time: 2.0, Action: DCPActionDir.LK, Cost: -22.0, CostLC: 0.0, CostS: -4.1, CostV: -17.9, S: 34.9, V: 17.9, A: 0.4
#   Time: 3.0, Action: DCPActionDir.LK, Cost: -24.5, CostLC: 0.0, CostS: -6.2, CostV: -18.3, S: 53.0, V: 18.3, A: 0.4
#   Time: 4.0, Action: DCPActionDir.LK, Cost: -27.0, CostLC: 0.0, CostS: -8.4, CostV: -18.7, S: 71.4, V: 18.7, A: 0.4
#   Time: 5.0, Action: DCPActionDir.LK, Cost:
#   Time: 3.0, Action: DCPActionDir.LK, Cost: -24.5, CostLC: 0.0, CostS: -6.2, CostV: -18.3, S: 53.0, V: 18.3, A: 0.4
#   Time: 4.0, Action: DCPActionDir.LK, Cost: -27.0, CostLC: 0.0, CostS: -8.4, CostV: -18.7, S: 71.4, V: 18.7, A: 0.4
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -29.7, CostLC: 0.0, CostS: -10.6, CostV: -19.1, S: 90.3, V: 19.1, A: 0.4
#   Time: 6.0, Action: DCPActionDir.LK, Cost: -32.3, CostLC: 0.0, CostS: -12.9, CostV: -19.5, S: 109.6, V: 19.5, A: 0.4
#   Time: 11.0, Action: DCPActionDir.LC_RIGHT, Cost: -45.3, CostLC: 1.0, CostS: -24.8, CostV: -21.4, S: 211.8, V: 21.4, A: 0.4
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -48.2, CostLC: 0.0, CostS: -27.4, CostV: -21.8, S: 233.6, V: 21.8, A: 0.4
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b755fa0e-7504-48cf-8bfe-b128cde1594d">Loading BokehJS ...</span>
#     </div>
#   <div id="c0de62e4-7852-4cc1-91d7-bcd3108fa79b" data-root-id="p1512" style="display: contents;"></div>

# %% [markdown]
# # f_18

# %%
file_name = 'f_18.json'
file = file_path + file_name
dcp_tree = pybind_dcp_tree.DCPTree()
root_node = pybind_dcp_tree.DCPTreeNodeData()
ego_info = pybind_ilqr.IDMCarInfo(0.0, 24.914828847854945, 0.21574629843235016, 4.886)
root_node.obs_pos = dcp_tree_plot.read_json(file)
root_node.ego_pos = ego_info
dcp_tree.set_IDM_params(1.0, 3, 24.914828847854945, 27)
root_node.tree_trace.clear()
dcp_tree.update_tree(root_node)
dcp_tree.show()
all_paths = dcp_tree.get_all_path()
print("all paths size is: ")
print(len(all_paths))
sorted_paths = sorted(all_paths, key=lambda x: x[-1][0])
top_10_min_cost_paths = sorted_paths[:15]
for i, path in enumerate(top_10_min_cost_paths):
#     print(f"Path {i+1} with last step cost {path[-1][0]}:")
    print("Path {} with last step cost {:.1f}:".format(i+1, path[-1][0]))
    for step in path:
#         print(f"  Time: {step[1]}, Action: {step[2]}, Cost: {step[0]}")
        print("  Time: {}, Action: {}, Cost: {:.1f}, CostLC: {:.1f}, CostS: {:.1f}, CostV: {:.1f}, S: {:.1f}, V: {:.1f}, A: {:.1f}". \
                      format(step[1], step[2], step[0], \
                             step[3].cost_lc, \
                            step[3].cost_s, \
                            step[3].cost_v,
                            step[3].s,
                            step[3].v,
                            step[3].a))
    print()
sequences = dcp_tree_plot.converted_sequences(top_10_min_cost_paths)
# pprint(sequences)
plot = dcp_tree_plot.plot_dcp_tree_node(sequences)
output_notebook()
p = dcp_tree_plot.plot_lane_and_objs(root_node.obs_pos, ego_info)
show(column(p, plot))
# Out:
# all paths size is:
# 15
# Path 1 with last step cost -51.1:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0, CostLC: 0.0, CostS: 0.0, CostV: 0.0, S: 0.0, V: 0.0, A: 0.0
#   Time: 5.0, Action: DCPActionDir.LC_LEFT, Cost: -35.5, CostLC: 1.0, CostS: -10.3, CostV: -26.2, S: 127.8, V: 26.2, A: 0.3
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -51.1, CostLC: 0.0, CostS: -25.2, CostV: -26.9, S: 314.0, V: 26.9, A: 0.1
#
# Path 2 with last step cost -51.1:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0, CostLC: 0.0, CostS: 0.0, CostV: 0.0, S: 0.0, V: 0.0, A: 0.0
#   Time: 5.0, Action: DCPActionDir.LC_RIGHT, Cost: -35.5, CostLC: 1.0, CostS: -10.3, CostV: -26.2, S: 127.8, V: 26.2, A: 0.3
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -51.1, CostLC: 0.0, CostS: -25.2, CostV: -26.9, S: 314.0, V: 26.9, A: 0.1
#
# Path 3 with last step cost -51.0:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0, CostLC: 0.0, CostS: 0.0, CostV: 0.0, S: 0.0, V: 0.0, A: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: -27.2, CostLC: 0.0, CostS: -2.0, CostV: -25.2, S: 25.0, V: 25.2, A: 0.3
#   Time: 6.0, Action: DCPActionDir.LC_LEFT, Cost: -37.7, CostLC: 1.0, CostS: -12.3, CostV: -26.3, S: 153.7, V: 26.3, A: 0.2
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -51.0, CostLC: 0.0, CostS: -25.2, CostV: -26.8, S: 313.5, V: 26.8, A: 0.1
#
# Path 4 with last step cost -51.0:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0, CostLC: 0.0, CostS: 0.0, CostV: 0.0, S: 0.0, V: 0.0, A: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: -27.2, CostLC: 0.0, CostS: -2.0, CostV: -25.2, S: 25.0, V: 25.2, A: 0.3
#   Time: 6.0, Action: DCPActionDir.LC_RIGHT, Cost: -37.7, CostLC: 1.0, CostS: -12.3, CostV: -26.3, S: 153.7, V: 26.3, A: 0.2
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -51.0, CostLC: 0.0, CostS: -25.2, CostV: -26.8, S: 313.5, V: 26.8, A: 0.1
#
# Path 5 with last step cost -50.9:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0, CostLC: 0.0, CostS: 0.0, CostV: 0.0, S: 0.0, V: 0.0, A: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: -27.2, CostLC: 0.0, CostS: -2.0, CostV: -25.2, S: 25.0, V: 25.2, A: 0.3
#   Time: 2.0, Action: DCPActionDir.LK, Cost: -29.4, CostLC: 0.0, CostS: -4.0, CostV: -25.4, S: 50.3, V: 25.4, A: 0.2
#   Time: 7.0, Action: DCPActionDir.LC_LEFT, Cost: -39.8, CostLC: 1.0, CostS: -14.4, CostV: -26.4, S: 179.8, V: 26.4, A: 0.2
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -50.9, CostLC: 0.0, CostS: -25.1, CostV: -26.8, S: 313.1, V: 26.8, A: 0.1
#
# Path 6 with last step cost -50.9:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0, CostLC: 0.0, CostS: 0.0, CostV: 0.0, S: 0.0, V: 0.0, A: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: -27.2, CostLC: 0.0, CostS: -2.0, CostV: -25.2, S: 25.0, V: 25.2, A: 0.3
#   Time: 2.0, Action: DCPActionDir.LK, Cost: -29.4, CostLC: 0.0, CostS: -4.0, CostV: -25.4, S: 50.3, V: 25.4, A: 0.2
#   Time: 7.0, Action: DCPActionDir.LC_RIGHT, Cost: -39.8, CostLC: 1.0, CostS: -14.4, CostV: -26.4, S: 179.8, V: 26.4, A: 0.2
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -50.9, CostLC: 0.0, CostS: -25.1, CostV: -26.8, S: 313.1, V: 26.8, A: 0.1
#
# Path 7 with last step cost -50.9:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0, CostLC: 0.0, CostS: 0.0, CostV: 0.0, S: 0.0, V: 0.0, A: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: -27.2, CostLC: 0.0, CostS: -2.0, CostV: -25.2, S: 25.0, V: 25.2, A: 0.3
#   Time: 2.0, Action: DCPActionDir.LK, Cost: -29.4, CostLC: 0.0, CostS: -4.0, CostV: -25.4, S: 50.3, V: 25.4, A: 0.2
#   Time: 3.0, Action: DCPActionDir.LK, Cost: -31.7, CostLC: 0.0, CostS: -6.1, CostV: -25.6, S: 75.8, V: 25.6, A: 0.2
#   Time: 8.0, Action: DCPActionDir.LC_LEFT, Cost: -42.0, CostLC: 1.0, CostS: -16.5, CostV: -26.5, S: 206.0, V: 26.5, A: 0.2
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -50.9, CostLC: 0.0, CostS: -25.1, CostV: -26.8, S: 312.8, V: 26.8, A: 0.1
#
# Path 8 with last step cost -50.9:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0, CostLC: 0.0, CostS: 0.0, CostV: 0.0, S: 0.0, V: 0.0, A: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: -27.2, CostLC: 0.0, CostS: -2.0, CostV: -25.2, S: 25.0, V: 25.2, A: 0.3
#   Time: 2.0, Action: DCPActionDir.LK, Cost: -29.4, CostLC: 0.0, CostS: -4.0, CostV: -25.4, S: 50.3, V: 25.4, A: 0.2
#   Time: 3.0, Action: DCPActionDir.LK, Cost: -31.7, CostLC: 0.0, CostS: -6.1, CostV: -25.6, S: 75.8, V: 25.6, A: 0.2
#   Time: 8.0, Action: DCPActionDir.LC_RIGHT, Cost: -42.0, CostLC: 1.0, CostS: -16.5, CostV: -26.5, S: 206.0, V: 26.5, A: 0.2
#   Time: 12.01, Action: DCPActionDir.LK, Cost:
#   Time: 6.0, Action: DCPActionDir.LK, Cost: -38.2, CostLC: 0.0, CostS: -12.3, CostV: -25.9, S: 153.3, V: 25.9, A: -0.0
#   Time: 7.0, Action: DCPActionDir.LK, Cost: -40.1, CostLC: 0.0, CostS: -14.4, CostV: -25.8, S: 179.1, V: 25.8, A: -0.2
#   Time: 8.0, Action: DCPActionDir.LK, Cost: -41.9, CostLC: 0.0, CostS: -16.4, CostV: -25.5, S: 204.7, V: 25.5, A: -0.3
#   Time: 9.0, Action: DCPActionDir.LK, Cost: -43.6, CostLC: 0.0, CostS: -18.5, CostV: -25.1, S: 230.0, V: 25.1, A: -0.4
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -45.1, CostLC: 0.0, CostS: -20.5, CostV: -24.7, S: 254.9, V: 24.7, A: -0.4
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -46.6, CostLC: 0.0, CostS: -22.4, CostV: -24.2, S: 279.3, V: 24.2, A: -0.4
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -48.2, CostLC: 0.0, CostS: -24.4, CostV: -23.8, S: 303.4, V: 23.8, A: -0.4
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b5bbd550-7bd4-4742-8073-ee981c9a45bd">Loading BokehJS ...</span>
#     </div>
#   <div id="be461748-3bdb-45ad-9903-256b61a9198b" data-root-id="p2536" style="display: contents;"></div>

# %% [markdown]
# # f_3

# %%
file_name = 'f_3.json'
file = file_path + file_name
dcp_tree = pybind_dcp_tree.DCPTree()
root_node = pybind_dcp_tree.DCPTreeNodeData()
ego_info = pybind_ilqr.IDMCarInfo(0.0, 24.914828847854945, 0.21574629843235016, 4.886)
root_node.obs_pos = dcp_tree_plot.read_json(file)
root_node.ego_pos = ego_info
dcp_tree.set_IDM_params(1.0, 3, 24.914828847854945, 27)
root_node.tree_trace.clear()
dcp_tree.update_tree(root_node)
dcp_tree.show()
all_paths = dcp_tree.get_all_path()
print("all paths size is: ")
print(len(all_paths))
sorted_paths = sorted(all_paths, key=lambda x: x[-1][0])
top_10_min_cost_paths = sorted_paths[:15]
for i, path in enumerate(top_10_min_cost_paths):
#     print(f"Path {i+1} with last step cost {path[-1][0]}:")
    print("Path {} with last step cost {:.1f}:".format(i+1, path[-1][0]))
    for step in path:
#         print(f"  Time: {step[1]}, Action: {step[2]}, Cost: {step[0]}")
        print("  Time: {}, Action: {}, Cost: {:.1f}, CostLC: {:.1f}, CostS: {:.1f}, CostV: {:.1f}, S: {:.1f}, V: {:.1f}, A: {:.1f}". \
                      format(step[1], step[2], step[0], \
                             step[3].cost_lc, \
                            step[3].cost_s, \
                            step[3].cost_v,
                            step[3].s,
                            step[3].v,
                            step[3].a))
    print()
sequences = dcp_tree_plot.converted_sequences(top_10_min_cost_paths)
# pprint(sequences)
plot = dcp_tree_plot.plot_dcp_tree_node(sequences)
output_notebook()
p = dcp_tree_plot.plot_lane_and_objs(root_node.obs_pos, ego_info)
show(column(p, plot))
# Out:
# Could not open the file
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/ws/gitlab.senseauto.com/common_math/algorithm/dcp_tree/notebook/../python_plot/dcp_tree_plot.py:182, in read_json(file)
#     181 try:
# --> 182     with open(file, 'r') as file:
#     183         j = json.load(file)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/SENSETIME/chengren1/ws/gitlab.senseauto.com/common_math/algorithm/dcp_tree/data/f_3.json'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[4], line 6
#       5 ego_info = pybind_ilqr.IDMCarInfo(0.0, 24.914828847854945, 0.21574629843235016, 4.886)
# ----> 6 root_node.obs_pos = dcp_tree_plot.read_json(file)
#       7 root_node.ego_pos = ego_info
#
# File ~/ws/gitlab.senseauto.com/common_math/algorithm/dcp_tree/notebook/../python_plot/dcp_tree_plot.py:186, in read_json(file)
#     185     print("Could not open the file")
# --> 186     sys.exit(1)
#     187 scenario_name = j["name"]
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/xfastplayer/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2121, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2118 if exception_only:
#    2119     stb = ['An exception has occurred, use %tb to see '
#    2120            'the full traceback.\n']
# -> 2121     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2122                                                      value))
#    2123 else:
#    2125     def contains_exceptiongroup(val):
#
# File ~/miniconda3/envs/xfastplayer/lib/python3.10/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~/miniconda3/envs/xfastplayer/lib/python3.10/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~/miniconda3/envs/xfastplayer/lib/python3.10/site-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~/miniconda3/envs/xfastplayer/lib/python3.10/site-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~/miniconda3/envs/xfastplayer/lib/python3.10/site-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~/miniconda3/envs/xfastplayer/lib/python3.10/site-packages/IPython/core/ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~/miniconda3/envs/xfastplayer/lib/python3.10/site-packages/IPython/core/ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'
