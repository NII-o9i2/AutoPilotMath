# %%
import sys
import numpy as np
import os
current_directory = os.getcwd()
relative_path1 = '../../build/env_simulator'
relative_path2 = '../../build/cilqr'
file_path1 = os.path.join(current_directory, relative_path1)
file_path2 = os.path.join(current_directory, relative_path2)
sys.path.append(file_path1)
sys.path.append(file_path2)
import pybind_env_simulator
relative_path3 = '../../env_simulator'
file_path3 = os.path.join(current_directory, relative_path3)
sys.path.append(file_path3)
relative_path4 = '../'
file_path4 = os.path.join(current_directory, relative_path4)
sys.path.append(file_path4)
relative_path5 = '../../build/dcp_tree'
file_path4 = os.path.join(current_directory, relative_path5)
sys.path.append(relative_path5)
relative_path6 = '../python_plot'
relative_path6 = os.path.join(current_directory, relative_path6)
sys.path.append(relative_path6)
import pybind_ilqr
import pybind_dcp_tree
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import WheelZoomTool
import json
from pprint import pprint
from collections import defaultdict
import itertools
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import LabelSet, ColumnDataSource
from python_plot import dcp_tree_plot
from bokeh.layouts import column, row
file_path = '/home/ws/pilotmdc_aarch64/senseauto-pilot-decision/common_math/algorithm/dcp_tree/data/'

# %% [markdown]
# # case1_empty_3_lanes

# %%
file_name = 'case1_empty_3_lanes.json'
file = file_path + file_name
dcp_tree = pybind_dcp_tree.DCPTree()
root_node = pybind_dcp_tree.DCPTreeNodeData()
ego_info = pybind_ilqr.IDMCarInfo(0.2, 16.6, 0.2, 5.0)
root_node.obs_pos = dcp_tree_plot.read_json(file)
root_node.ego_pos = ego_info
dcp_tree.set_IDM_params(1.0, 3, 16.6, 22.22)
root_node.tree_trace.clear()
dcp_tree.update_tree(root_node)
dcp_tree.show()
all_paths = dcp_tree.get_all_path()
sorted_paths = sorted(all_paths, key=lambda x: x[-1][0])
top_10_min_cost_paths = sorted_paths[:10]
for i, path in enumerate(top_10_min_cost_paths):
    print(f"Path {i+1} with last step cost {path[-1][0]}:")
    for step in path:
        print(f"  Time: {step[1]}, Action: {step[2]}, Cost: {step[0]}")
    print()
sequences = dcp_tree_plot.converted_sequences(top_10_min_cost_paths)
pprint(sequences)
plot = dcp_tree_plot.plot_dcp_tree_node(sequences)
output_notebook()
p = dcp_tree_plot.plot_lane_and_objs(root_node.obs_pos, ego_info)
show(column(p, plot))
# Out:
# Path 1 with last step cost -16.848682714234524:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -16.848682714234524
#
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (-16.848682714234524, 12.01, <DCPActionDir.LK: 0>)
# [[(10, 10, 0.0, 0.0, 'LK'), (10, 9, -16.848682714234524, 12.01, 'LK')]]
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="bba3d88d-56e7-4593-80eb-7afb02a15f59">Loading BokehJS ...</span>
#     </div>
#   <div id="baaf2941-b1cb-488c-93a0-6214ec7b2053" data-root-id="p1163" style="display: contents;"></div>

# %% [markdown]
# # case2_one_lane_cars

# %%
file_name = 'case2_crowded_3_lanes.json'
file = file_path + file_name
dcp_tree = pybind_dcp_tree.DCPTree()
root_node = pybind_dcp_tree.DCPTreeNodeData()
ego_info = pybind_ilqr.IDMCarInfo(0.2, 16.6, 0.2, 5.0)
root_node.obs_pos = dcp_tree_plot.read_json(file)
root_node.ego_pos = ego_info
dcp_tree.set_IDM_params(1.0, 3, 16.6, 22.22)
root_node.tree_trace.clear()
dcp_tree.update_tree(root_node)
dcp_tree.show()
all_paths = dcp_tree.get_all_path()
print("all paths size is: ")
print(len(all_paths))
sorted_paths = sorted(all_paths, key=lambda x: x[-1][0])
top_10_min_cost_paths = sorted_paths[:10]
for i, path in enumerate(top_10_min_cost_paths):
    print(f"Path {i+1} with last step cost {path[-1][0]}:")
    for step in path:
        print(f"  Time: {step[1]}, Action: {step[2]}, Cost: {step[0]}")
    print()
sequences = dcp_tree_plot.converted_sequences(top_10_min_cost_paths)
# pprint(sequences)
plot = dcp_tree_plot.plot_dcp_tree_node(sequences)
output_notebook()
# show(plot)
p = dcp_tree_plot.plot_lane_and_objs(root_node.obs_pos, ego_info)

show(column(p, plot))
# Out:
# all paths size is:
# 1
# Path 1 with last step cost -13.183734630832138:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 3.1901099215946376
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.809397329401854
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.3544330905961086
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.1740643369060422
#   Time: 6.0, Action: DCPActionDir.LK, Cost: -2.7688245827745552
#   Time: 7.0, Action: DCPActionDir.LK, Cost: -4.4200828754307135
#   Time: 8.0, Action: DCPActionDir.LK, Cost: -6.1174026218073365
#   Time: 9.0, Action: DCPActionDir.LK, Cost: -7.850734287978394
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -9.611065702852294
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -11.390773026102572
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -13.183734630832138
#
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (3.1901099215946376, 2.0, <DCPActionDir.LK: 0>)
# (1.809397329401854, 3.0, <DCPActionDir.LK: 0>)
# (0.3544330905961086, 4.0, <DCPActionDir.LK: 0>)
# (-1.1740643369060422, 5.0, <DCPActionDir.LK: 0>)
# (-2.7688245827745552, 6.0, <DCPActionDir.LK: 0>)
# (-4.4200828754307135, 7.0, <DCPActionDir.LK: 0>)
# (-6.1174026218073365, 8.0, <DCPActionDir.LK: 0>)
# (-7.850734287978394, 9.0, <DCPActionDir.LK: 0>)
# (-9.611065702852294, 10.0, <DCPActionDir.LK: 0>)
# (-11.390773026102572, 11.0, <DCPActionDir.LK: 0>)
# (-13.183734630832138, 12.0, <DCPActionDir.LK: 0>)
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c859411e-7495-4f16-9fb2-c69676b071c8">Loading BokehJS ...</span>
#     </div>
#   <div id="c2e08c8a-5278-4263-bad9-ea41350f94a1" data-root-id="p1696" style="display: contents;"></div>

# %% [markdown]
# # case3_one_lane_slow_car

# %%
file_name = 'case3_one_lane_slow_car.json'
file = file_path + file_name
dcp_tree = pybind_dcp_tree.DCPTree()
root_node = pybind_dcp_tree.DCPTreeNodeData()
ego_info = pybind_ilqr.IDMCarInfo(0.2, 16.6, 0.2, 5.0)
root_node.obs_pos = dcp_tree_plot.read_json(file)
root_node.ego_pos = ego_info
dcp_tree.set_IDM_params(1.0, 3, 16.6, 22.22)
root_node.tree_trace.clear()
dcp_tree.update_tree(root_node)
dcp_tree.show()
all_paths = dcp_tree.get_all_path()
print("all paths size is: ")
pprint(len(all_paths))
sorted_paths = sorted(all_paths, key=lambda x: x[-1][0])
top_10_min_cost_paths = sorted_paths[:10]
for i, path in enumerate(top_10_min_cost_paths):
    print(f"Path {i+1} with last step cost {path[-1][0]}:")
    for step in path:
        print(f"  Time: {step[1]}, Action: {step[2]}, Cost: {step[0]}")
    print()

sequences = dcp_tree_plot.converted_sequences(top_10_min_cost_paths)
# pprint(sequences)
plot = dcp_tree_plot.plot_dcp_tree_node(sequences)
output_notebook()
p = dcp_tree_plot.plot_lane_and_objs(root_node.obs_pos, ego_info)

show(column(p, plot))
# Out:
# all paths size is:
# 5
# Path 1 with last step cost -16.856669225556125:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: -1.3150555273304807
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -16.856669225556125
#
# Path 2 with last step cost -15.856669225556125:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 5.0, Action: DCPActionDir.LC_LEFT, Cost: -0.3150555273304807
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.856669225556125
#
# Path 3 with last step cost -15.856669225556125:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 5.0, Action: DCPActionDir.LC_RIGHT, Cost: -0.3150555273304807
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.856669225556125
#
# Path 4 with last step cost -12.029930605739596:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 6.0, Action: DCPActionDir.LC_LEFT, Cost: -1.6244357768208202
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -12.029930605739596
#
# Path 5 with last step cost -12.029930605739596:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 6.0, Action: DCPActionDir.LC_RIGHT, Cost: -1.6244357768208202
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -12.029930605739596
#
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (-1.3150555273304807, 2.0, <DCPActionDir.LK: 0>)
# (-16.856669225556125, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (-0.3150555273304807, 5.0, <DCPActionDir.LC_LEFT: -1>)
# (-15.856669225556125, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (-0.3150555273304807, 5.0, <DCPActionDir.LC_RIGHT: 1>)
# (-15.856669225556125, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (-1.6244357768208202, 6.0, <DCPActionDir.LC_LEFT: -1>)
# (-12.029930605739596, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (-1.6244357768208202, 6.0, <DCPActionDir.LC_RIGHT: 1>)
# (-12.029930605739596, 12.01, <DCPActionDir.LK: 0>)
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="dc37f528-c4f0-46e4-aaef-d5dd7d09552b">Loading BokehJS ...</span>
#     </div>
#   <div id="fff9ebfe-835d-4e2b-a625-b2305d5e915d" data-root-id="p2617" style="display: contents;"></div>

# %% [markdown]
# # case4_two_lane_cars_too_close

# %%
file_name = 'case4_two_lane_cars_too_close.json'
file = file_path + file_name
dcp_tree = pybind_dcp_tree.DCPTree()
root_node = pybind_dcp_tree.DCPTreeNodeData()
ego_info = pybind_ilqr.IDMCarInfo(0.2, 16.6, 0.2, 5.0)
root_node.obs_pos = dcp_tree_plot.read_json(file)
root_node.ego_pos = ego_info
dcp_tree.set_IDM_params(1.0, 3, 16.6, 22.22)
root_node.tree_trace.clear()
dcp_tree.update_tree(root_node)
dcp_tree.show()
all_paths = dcp_tree.get_all_path()
print("all paths size is: ")
print(len(all_paths))
sorted_paths = sorted(all_paths, key=lambda x: x[-1][0])
top_10_min_cost_paths = sorted_paths[:10]
for i, path in enumerate(top_10_min_cost_paths):
    print(f"Path {i+1} with last step cost {path[-1][0]}:")
    for step in path:
        print(f"  Time: {step[1]}, Action: {step[2]}, Cost: {step[0]}")
    print()
sequences = dcp_tree_plot.converted_sequences(top_10_min_cost_paths)
# pprint(sequences)
plot = dcp_tree_plot.plot_dcp_tree_node(sequences)
output_notebook()
p = dcp_tree_plot.plot_lane_and_objs(root_node.obs_pos, ego_info)
show(column(p, plot))
# Out:
# all paths size is:
# 15
# Path 1 with last step cost -15.856669225556125:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 5.0, Action: DCPActionDir.LC_LEFT, Cost: -0.3150555273304807
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.856669225556125
#
# Path 2 with last step cost -15.856669225556125:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 5.0, Action: DCPActionDir.LC_RIGHT, Cost: -0.3150555273304807
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.856669225556125
#
# Path 3 with last step cost -15.354572173580422:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.204531289516926
#   Time: 6.0, Action: DCPActionDir.LC_LEFT, Cost: -2.287370223100707
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.354572173580422
#
# Path 4 with last step cost -15.354572173580422:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.204531289516926
#   Time: 6.0, Action: DCPActionDir.LC_RIGHT, Cost: -2.287370223100707
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.354572173580422
#
# Path 5 with last step cost -15.01245537232397:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.204531289516926
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.125748200235222
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 2.065625604825481
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.04013794903284129
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.944242187604492
#   Time: 6.0, Action: DCPActionDir.LK, Cost: -3.888064238112487
#   Time: 7.0, Action: DCPActionDir.LK, Cost: -5.795989958042633
#   Time: 8.0, Action: DCPActionDir.LK, Cost: -7.674409920040777
#   Time: 9.0, Action: DCPActionDir.LK, Cost: -9.529883623984531
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -11.368302523039695
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -13.19455044555177
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -15.01245537232397
#
# Path 6 with last step cost -14.871632420016118:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.204531289516926
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.125748200235222
#   Time: 7.0, Action: DCPActionDir.LC_LEFT, Cost: -4.229633782373986
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -14.871632420016118
#
# Path 7 with last step cost -14.871632420016118:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.204531289516926
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.125748200235222
#   Time: 7.0, Action: DCPActionDir.LC_RIGHT, Cost: -4.229633782373986
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -14.871632420016118
#
# Path 8 with last step cost -14.449225387448033:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.204531289516926
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.125748200235222
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 2.065625604825481
#   Time: 8.0, Action: DCPActionDir.LC_LEFT, Cost: -6.1416895254310635
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -14.449225387448033
#
# Path 9 with last step cost -14.449225387448033:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.204531289516926
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.125748200235222
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 2.065625604825481
#   Time: 8.0, Action: DCPActionDir.LC_RIGHT, Cost: -6.1416895254310635
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -14.449225387448033
#
# Path 10 with last step cost -14.108416804727556:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.204531289516926
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.125748200235222
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 2.065625604825481
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.04013794903284129
#   Time: 9.0, Action: DCPActionDir.LC_LEFT, Cost: -8.026592845233187
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -14.108416804727556
#
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (-0.3150555273304807, 5.0, <DCPActionDir.LC_LEFT: -1>)
# (-15.856669225556125, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (-0.3150555273304807, 5.0, <DCPActionDir.LC_RIGHT: 1>)
# (-15.856669225556125, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.204531289516926, 1.0, <DCPActionDir.LK: 0>)
# (-2.287370223100707, 6.0, <DCPActionDir.LC_LEFT: -1>)
# (-15.354572173580422, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.204531289516926, 1.0, <DCPActionDir.LK: 0>)
# (-2.287370223100707, 6.0, <DCPActionDir.LC_RIGHT: 1>)
# (-15.354572173580422, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.204531289516926, 1.0, <DCPActionDir.LK: 0>)
# (4.125748200235222, 2.0, <DCPActionDir.LK: 0>)
# (2.065625604825481, 3.0, <DCPActionDir.LK: 0>)
# (0.04013794903284129, 4.0, <DCPActionDir.LK: 0>)
# (-1.944242187604492, 5.0, <DCPActionDir.LK: 0>)
# (-3.888064238112487, 6.0, <DCPActionDir.LK: 0>)
# (-5.795989958042633, 7.0, <DCPActionDir.LK: 0>)
# (-7.674409920040777, 8.0, <DCPActionDir.LK: 0>)
# (-9.529883623984531, 9.0, <DCPActionDir.LK: 0>)
# (-11.368302523039695, 10.0, <DCPActionDir.LK: 0>)
# (-13.19455044555177, 11.0, <DCPActionDir.LK: 0>)
# (-15.01245537232397, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.204531289516926, 1.0, <DCPActionDir.LK: 0>)
# (4.125748200235222, 2.0, <DCPActionDir.LK: 0>)
# (-4.229633782373986, 7.0, <DCPActionDir.LC_LEFT: -1>)
# (-14.871632420016118, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.204531289516926, 1.0, <DCPActionDir.LK: 0>)
# (4.125748200235222, 2.0, <DCPActionDir.LK: 0>)
# (-4.229633782373986, 7.0, <DCPActionDir.LC_RIGHT: 1>)
# (-14.871632420016118, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.204531289516926, 1.0, <DCPActionDir.LK: 0>)
# (4.125748200235222, 2.0, <DCPActionDir.LK: 0>)
# (2.065625604825481, 3.0, <DCPActionDir.LK: 0>)
# (-6.1416895254310635, 8.0, <DCPActionDir.LC_LEFT: -1>)
# (-14.449225387448033, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.204531289516926, 1.0, <DCPActionDir.LK: 0>)
# (4.125748200235222, 2.0, <DCPActionDir.LK: 0>)
# (2.065625604825481, 3.0, <DCPActionDir.LK: 0>)
# (-6.1416895254310635, 8.0, <DCPActionDir.LC_RIGHT: 1>)
# (-14.449225387448033, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.204531289516926, 1.0, <DCPActionDir.LK: 0>)
# (4.125748200235222, 2.0, <DCPActionDir.LK: 0>)
# (2.065625604825481, 3.0, <DCPActionDir.LK: 0>)
# (0.04013794903284129, 4.0, <DCPActionDir.LK: 0>)
# (-8.026592845233187, 9.0, <DCPActionDir.LC_LEFT: -1>)
# (-14.108416804727556, 12.01, <DCPActionDir.LK: 0>)
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b9f13288-106e-45bb-af2f-2c885f2f7837">Loading BokehJS ...</span>
#     </div>
#   <div id="bd45d85a-b6de-4e82-a655-f41b98d373d3" data-root-id="p3679" style="display: contents;"></div>

# %% [markdown]
# # case5_only_have_behind_ego_cars

# %%
file_name = 'case5_only_have_behind_ego_cars.json'
file = file_path + file_name
dcp_tree = pybind_dcp_tree.DCPTree()
root_node = pybind_dcp_tree.DCPTreeNodeData()
ego_info = pybind_ilqr.IDMCarInfo(0.2, 16.6, 0.2, 5.0)
root_node.obs_pos = dcp_tree_plot.read_json(file)
root_node.ego_pos = ego_info
dcp_tree.set_IDM_params(1.0, 3, 16.6, 22.22)
root_node.tree_trace.clear()
dcp_tree.update_tree(root_node)
dcp_tree.show()
all_paths = dcp_tree.get_all_path()
print("all paths size is: ")
print(len(all_paths))
sorted_paths = sorted(all_paths, key=lambda x: x[-1][0])
top_10_min_cost_paths = sorted_paths[:10]
for i, path in enumerate(top_10_min_cost_paths):
    print(f"Path {i+1} with last step cost {path[-1][0]}:")
    for step in path:
        print(f"  Time: {step[1]}, Action: {step[2]}, Cost: {step[0]}")
    print()
sequences = dcp_tree_plot.converted_sequences(top_10_min_cost_paths)
# pprint(sequences)
plot = dcp_tree_plot.plot_dcp_tree_node(sequences)
output_notebook()
p = dcp_tree_plot.plot_lane_and_objs(root_node.obs_pos, ego_info)
show(column(p, plot))
# Out:
# all paths size is:
# 1
# Path 1 with last step cost -16.848682714234524:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -16.848682714234524
#
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (-16.848682714234524, 12.01, <DCPActionDir.LK: 0>)
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fe26c458-81f3-4457-bc02-72bb0b666fcd">Loading BokehJS ...</span>
#     </div>
#   <div id="daaf14e9-ca67-4cb7-9e1c-452b4bfe529d" data-root-id="p4886" style="display: contents;"></div>

# %% [markdown]
# # case6_cur_left_lane_2_cars

# %%
file_name = 'case6_cur_left_lane_2_cars.json'
file = file_path + file_name
dcp_tree = pybind_dcp_tree.DCPTree()
root_node = pybind_dcp_tree.DCPTreeNodeData()
ego_info = pybind_ilqr.IDMCarInfo(0.2, 16.6, 0.2, 5.0)
root_node.obs_pos = dcp_tree_plot.read_json(file)
root_node.ego_pos = ego_info
dcp_tree.set_IDM_params(1.0, 3, 16.6, 22.22)
root_node.tree_trace.clear()
dcp_tree.update_tree(root_node)
dcp_tree.show()
all_paths = dcp_tree.get_all_path()
print("all paths size is: ")
print(len(all_paths))
sorted_paths = sorted(all_paths, key=lambda x: x[-1][0])
top_10_min_cost_paths = sorted_paths[:10]
for i, path in enumerate(top_10_min_cost_paths):
    print(f"Path {i+1} with last step cost {path[-1][0]}:")
    for step in path:
        print(f"  Time: {step[1]}, Action: {step[2]}, Cost: {step[0]}")
    print()
sequences = dcp_tree_plot.converted_sequences(top_10_min_cost_paths)
# pprint(sequences)
plot = dcp_tree_plot.plot_dcp_tree_node(sequences)
output_notebook()
p = dcp_tree_plot.plot_lane_and_objs(root_node.obs_pos, ego_info)
show(column(p, plot))
# Out:
# all paths size is:
# 15
# Path 1 with last step cost -15.856669225556125:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 5.0, Action: DCPActionDir.LC_RIGHT, Cost: -0.3150555273304807
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.856669225556125
#
# Path 2 with last step cost -12.263521580716064:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.13253251359794227
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.1892178347388658
#   Time: 6.0, Action: DCPActionDir.LK, Cost: -2.567831288225115
#   Time: 7.0, Action: DCPActionDir.LK, Cost: -4.002463655328672
#   Time: 8.0, Action: DCPActionDir.LK, Cost: -5.492335675939239
#   Time: 9.0, Action: DCPActionDir.LK, Cost: -7.049022480799899
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -8.714335286617107
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -10.461006491298438
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -12.263521580716064
#
# Path 3 with last step cost -12.029930605739596:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 6.0, Action: DCPActionDir.LC_RIGHT, Cost: -1.6244357768208202
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -12.029930605739596
#
# Path 4 with last step cost -11.305884757416816:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.13253251359794227
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.1892178347388658
#   Time: 10.0, Action: DCPActionDir.LC_LEFT, Cost: -7.619569464002426
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -9.451764724331992
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.305884757416816
#
# Path 5 with last step cost -11.298653926110338:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 7.0, Action: DCPActionDir.LC_LEFT, Cost: -2.983388668528007
#   Time: 8.0, Action: DCPActionDir.LK, Cost: -4.480845810931103
#   Time: 9.0, Action: DCPActionDir.LK, Cost: -6.05970625592443
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -7.7395920911208265
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -9.493973075350542
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.298653926110338
#
# Path 6 with last step cost -11.290608896519013:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.13253251359794227
#   Time: 9.0, Action: DCPActionDir.LC_LEFT, Cost: -6.0202448135016615
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -7.713616546845788
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -9.478397447735171
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.290608896519013
#
# Path 7 with last step cost -11.288205644850445:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 8.0, Action: DCPActionDir.LC_LEFT, Cost: -4.474635229259501
#   Time: 9.0, Action: DCPActionDir.LK, Cost: -6.0503817068688965
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -7.72869023009676
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -9.482807973594255
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.288205644850445
#
# Path 8 with last step cost -11.273814294430567:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.13253251359794227
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.1892178347388658
#   Time: 6.0, Action: DCPActionDir.LK, Cost: -2.567831288225115
#   Time: 11.0, Action: DCPActionDir.LC_LEFT, Cost: -9.272002204933909
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.273814294430567
#
# Path 9 with last step cost -11.012380230601355:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 7.0, Action: DCPActionDir.LC_RIGHT, Cost: -2.983388668528007
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -11.012380230601355
#
# Path 10 with last step cost -11.008994428625593:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 8.0, Action: DCPActionDir.LC_RIGHT, Cost: -4.474635229259501
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -11.008994428625593
#
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (-0.3150555273304807, 5.0, <DCPActionDir.LC_RIGHT: 1>)
# (-15.856669225556125, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (0.13253251359794227, 4.0, <DCPActionDir.LK: 0>)
# (-1.1892178347388658, 5.0, <DCPActionDir.LK: 0>)
# (-2.567831288225115, 6.0, <DCPActionDir.LK: 0>)
# (-4.002463655328672, 7.0, <DCPActionDir.LK: 0>)
# (-5.492335675939239, 8.0, <DCPActionDir.LK: 0>)
# (-7.049022480799899, 9.0, <DCPActionDir.LK: 0>)
# (-8.714335286617107, 10.0, <DCPActionDir.LK: 0>)
# (-10.461006491298438, 11.0, <DCPActionDir.LK: 0>)
# (-12.263521580716064, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (-1.6244357768208202, 6.0, <DCPActionDir.LC_RIGHT: 1>)
# (-12.029930605739596, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (0.13253251359794227, 4.0, <DCPActionDir.LK: 0>)
# (-1.1892178347388658, 5.0, <DCPActionDir.LK: 0>)
# (-7.619569464002426, 10.0, <DCPActionDir.LC_LEFT: -1>)
# (-9.451764724331992, 11.0, <DCPActionDir.LK: 0>)
# (-11.305884757416816, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (-2.983388668528007, 7.0, <DCPActionDir.LC_LEFT: -1>)
# (-4.480845810931103, 8.0, <DCPActionDir.LK: 0>)
# (-6.05970625592443, 9.0, <DCPActionDir.LK: 0>)
# (-7.7395920911208265, 10.0, <DCPActionDir.LK: 0>)
# (-9.493973075350542, 11.0, <DCPActionDir.LK: 0>)
# (-11.298653926110338, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (0.13253251359794227, 4.0, <DCPActionDir.LK: 0>)
# (-6.0202448135016615, 9.0, <DCPActionDir.LC_LEFT: -1>)
# (-7.713616546845788, 10.0, <DCPActionDir.LK: 0>)
# (-9.478397447735171, 11.0, <DCPActionDir.LK: 0>)
# (-11.290608896519013, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (-4.474635229259501, 8.0, <DCPActionDir.LC_LEFT: -1>)
# (-6.0503817068688965, 9.0, <DCPActionDir.LK: 0>)
# (-7.72869023009676, 10.0, <DCPActionDir.LK: 0>)
# (-9.482807973594255, 11.0, <DCPActionDir.LK: 0>)
# (-11.288205644850445, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (0.13253251359794227, 4.0, <DCPActionDir.LK: 0>)
# (-1.1892178347388658, 5.0, <DCPActionDir.LK: 0>)
# (-2.567831288225115, 6.0, <DCPActionDir.LK: 0>)
# (-9.272002204933909, 11.0, <DCPActionDir.LC_LEFT: -1>)
# (-11.273814294430567, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (-2.983388668528007, 7.0, <DCPActionDir.LC_RIGHT: 1>)
# (-11.012380230601355, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (-4.474635229259501, 8.0, <DCPActionDir.LC_RIGHT: 1>)
# (-11.008994428625593, 12.01, <DCPActionDir.LK: 0>)
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="caa7a293-7a8d-461c-8fed-7e37adbe2d3c">Loading BokehJS ...</span>
#     </div>
#   <div id="bc3c2a9e-8dd4-41d7-8e76-ce094ac807f8" data-root-id="p6017" style="display: contents;"></div>

# %% [markdown]
# # case7_cur_right_lane_2_cars

# %%
file_name = 'case7_cur_right_lane_2_cars.json'
file = file_path + file_name
dcp_tree = pybind_dcp_tree.DCPTree()
root_node = pybind_dcp_tree.DCPTreeNodeData()
ego_info = pybind_ilqr.IDMCarInfo(0.2, 16.6, 0.2, 5.0)
root_node.obs_pos = dcp_tree_plot.read_json(file)
root_node.ego_pos = ego_info
dcp_tree.set_IDM_params(1.0, 3, 16.6, 22.22)
root_node.tree_trace.clear()
dcp_tree.update_tree(root_node)
dcp_tree.show()
all_paths = dcp_tree.get_all_path()
print("all paths size is: ")
print(len(all_paths))
sorted_paths = sorted(all_paths, key=lambda x: x[-1][0])
top_10_min_cost_paths = sorted_paths[:10]
for i, path in enumerate(top_10_min_cost_paths):
    print(f"Path {i+1} with last step cost {path[-1][0]}:")
    for step in path:
        print(f"  Time: {step[1]}, Action: {step[2]}, Cost: {step[0]}")
    print()
sequences = dcp_tree_plot.converted_sequences(top_10_min_cost_paths)
# pprint(sequences)
plot = dcp_tree_plot.plot_dcp_tree_node(sequences)
output_notebook()
p = dcp_tree_plot.plot_lane_and_objs(root_node.obs_pos, ego_info)
show(column(p, plot))
# Out:
# all paths size is:
# 15
# Path 1 with last step cost -15.856669225556125:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 5.0, Action: DCPActionDir.LC_LEFT, Cost: -0.3150555273304807
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.856669225556125
#
# Path 2 with last step cost -12.263521580716064:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.13253251359794227
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.1892178347388658
#   Time: 6.0, Action: DCPActionDir.LK, Cost: -2.567831288225115
#   Time: 7.0, Action: DCPActionDir.LK, Cost: -4.002463655328672
#   Time: 8.0, Action: DCPActionDir.LK, Cost: -5.492335675939239
#   Time: 9.0, Action: DCPActionDir.LK, Cost: -7.049022480799899
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -8.714335286617107
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -10.461006491298438
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -12.263521580716064
#
# Path 3 with last step cost -12.029930605739596:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 6.0, Action: DCPActionDir.LC_LEFT, Cost: -1.6244357768208202
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -12.029930605739596
#
# Path 4 with last step cost -11.305884757416816:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.13253251359794227
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.1892178347388658
#   Time: 10.0, Action: DCPActionDir.LC_RIGHT, Cost: -7.619569464002426
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -9.451764724331992
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.305884757416816
#
# Path 5 with last step cost -11.298653926110338:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 7.0, Action: DCPActionDir.LC_RIGHT, Cost: -2.983388668528007
#   Time: 8.0, Action: DCPActionDir.LK, Cost: -4.480845810931103
#   Time: 9.0, Action: DCPActionDir.LK, Cost: -6.05970625592443
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -7.7395920911208265
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -9.493973075350542
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.298653926110338
#
# Path 6 with last step cost -11.290608896519013:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.13253251359794227
#   Time: 9.0, Action: DCPActionDir.LC_RIGHT, Cost: -6.0202448135016615
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -7.713616546845788
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -9.478397447735171
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.290608896519013
#
# Path 7 with last step cost -11.288205644850445:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 8.0, Action: DCPActionDir.LC_RIGHT, Cost: -4.474635229259501
#   Time: 9.0, Action: DCPActionDir.LK, Cost: -6.0503817068688965
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -7.72869023009676
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -9.482807973594255
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.288205644850445
#
# Path 8 with last step cost -11.273814294430567:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.13253251359794227
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.1892178347388658
#   Time: 6.0, Action: DCPActionDir.LK, Cost: -2.567831288225115
#   Time: 11.0, Action: DCPActionDir.LC_RIGHT, Cost: -9.272002204933909
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.273814294430567
#
# Path 9 with last step cost -11.012380230601355:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 7.0, Action: DCPActionDir.LC_LEFT, Cost: -2.983388668528007
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -11.012380230601355
#
# Path 10 with last step cost -11.008994428625593:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 8.0, Action: DCPActionDir.LC_LEFT, Cost: -4.474635229259501
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -11.008994428625593
#
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (-0.3150555273304807, 5.0, <DCPActionDir.LC_LEFT: -1>)
# (-15.856669225556125, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (0.13253251359794227, 4.0, <DCPActionDir.LK: 0>)
# (-1.1892178347388658, 5.0, <DCPActionDir.LK: 0>)
# (-2.567831288225115, 6.0, <DCPActionDir.LK: 0>)
# (-4.002463655328672, 7.0, <DCPActionDir.LK: 0>)
# (-5.492335675939239, 8.0, <DCPActionDir.LK: 0>)
# (-7.049022480799899, 9.0, <DCPActionDir.LK: 0>)
# (-8.714335286617107, 10.0, <DCPActionDir.LK: 0>)
# (-10.461006491298438, 11.0, <DCPActionDir.LK: 0>)
# (-12.263521580716064, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (-1.6244357768208202, 6.0, <DCPActionDir.LC_LEFT: -1>)
# (-12.029930605739596, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (0.13253251359794227, 4.0, <DCPActionDir.LK: 0>)
# (-1.1892178347388658, 5.0, <DCPActionDir.LK: 0>)
# (-7.619569464002426, 10.0, <DCPActionDir.LC_RIGHT: 1>)
# (-9.451764724331992, 11.0, <DCPActionDir.LK: 0>)
# (-11.305884757416816, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (-2.983388668528007, 7.0, <DCPActionDir.LC_RIGHT: 1>)
# (-4.480845810931103, 8.0, <DCPActionDir.LK: 0>)
# (-6.05970625592443, 9.0, <DCPActionDir.LK: 0>)
# (-7.7395920911208265, 10.0, <DCPActionDir.LK: 0>)
# (-9.493973075350542, 11.0, <DCPActionDir.LK: 0>)
# (-11.298653926110338, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (0.13253251359794227, 4.0, <DCPActionDir.LK: 0>)
# (-6.0202448135016615, 9.0, <DCPActionDir.LC_RIGHT: 1>)
# (-7.713616546845788, 10.0, <DCPActionDir.LK: 0>)
# (-9.478397447735171, 11.0, <DCPActionDir.LK: 0>)
# (-11.290608896519013, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (-4.474635229259501, 8.0, <DCPActionDir.LC_RIGHT: 1>)
# (-6.0503817068688965, 9.0, <DCPActionDir.LK: 0>)
# (-7.72869023009676, 10.0, <DCPActionDir.LK: 0>)
# (-9.482807973594255, 11.0, <DCPActionDir.LK: 0>)
# (-11.288205644850445, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (0.13253251359794227, 4.0, <DCPActionDir.LK: 0>)
# (-1.1892178347388658, 5.0, <DCPActionDir.LK: 0>)
# (-2.567831288225115, 6.0, <DCPActionDir.LK: 0>)
# (-9.272002204933909, 11.0, <DCPActionDir.LC_RIGHT: 1>)
# (-11.273814294430567, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (-2.983388668528007, 7.0, <DCPActionDir.LC_LEFT: -1>)
# (-11.012380230601355, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (-4.474635229259501, 8.0, <DCPActionDir.LC_LEFT: -1>)
# (-11.008994428625593, 12.01, <DCPActionDir.LK: 0>)
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fbf5d19d-0718-4fcd-a82f-936204ac07fc">Loading BokehJS ...</span>
#     </div>
#   <div id="d5627cd4-fdfb-47ef-97da-c308921dd224" data-root-id="p7633" style="display: contents;"></div>

# %% [markdown]
# # case8_cur_left_right_3_cars

# %%
file_name = 'case8_cur_left_right_3_cars.json'
file = file_path + file_name
dcp_tree = pybind_dcp_tree.DCPTree()
root_node = pybind_dcp_tree.DCPTreeNodeData()
ego_info = pybind_ilqr.IDMCarInfo(0.2, 16.6, 0.2, 5.0)
root_node.obs_pos = dcp_tree_plot.read_json(file)
root_node.ego_pos = ego_info
dcp_tree.set_IDM_params(1.0, 3, 16.6, 22.22)
root_node.tree_trace.clear()
dcp_tree.update_tree(root_node)
dcp_tree.show()
all_paths = dcp_tree.get_all_path()
print("all paths size is: ")
print(len(all_paths))
sorted_paths = sorted(all_paths, key=lambda x: x[-1][0])
top_10_min_cost_paths = sorted_paths[:5]
for i, path in enumerate(top_10_min_cost_paths):
    print(f"Path {i+1} with last step cost {path[-1][0]}:")
    for step in path:
        print(f"  Time: {step[1]}, Action: {step[2]}, Cost: {step[0]}")
    print()
sequences = dcp_tree_plot.converted_sequences(top_10_min_cost_paths)
# pprint(sequences)
plot = dcp_tree_plot.plot_dcp_tree_node(sequences)
output_notebook()
p = dcp_tree_plot.plot_lane_and_objs(root_node.obs_pos, ego_info)
show(column(p, plot))
# Out:
# all paths size is:
# 15
# Path 1 with last step cost -12.263521580716064:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.13253251359794227
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.1892178347388658
#   Time: 6.0, Action: DCPActionDir.LK, Cost: -2.567831288225115
#   Time: 7.0, Action: DCPActionDir.LK, Cost: -4.002463655328672
#   Time: 8.0, Action: DCPActionDir.LK, Cost: -5.492335675939239
#   Time: 9.0, Action: DCPActionDir.LK, Cost: -7.049022480799899
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -8.714335286617107
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -10.461006491298438
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -12.263521580716064
#
# Path 2 with last step cost -11.305884757416816:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.13253251359794227
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.1892178347388658
#   Time: 10.0, Action: DCPActionDir.LC_LEFT, Cost: -7.619569464002426
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -9.451764724331992
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.305884757416816
#
# Path 3 with last step cost -11.305884757416816:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 1.3965014826854096
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.13253251359794227
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.1892178347388658
#   Time: 10.0, Action: DCPActionDir.LC_RIGHT, Cost: -7.619569464002426
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -9.451764724331992
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.305884757416816
#
# Path 4 with last step cost -11.298653926110338:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 7.0, Action: DCPActionDir.LC_LEFT, Cost: -2.983388668528007
#   Time: 8.0, Action: DCPActionDir.LK, Cost: -4.480845810931103
#   Time: 9.0, Action: DCPActionDir.LK, Cost: -6.05970625592443
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -7.7395920911208265
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -9.493973075350542
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.298653926110338
#
# Path 5 with last step cost -11.298653926110338:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 4.516867469879519
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 2.6016856919313485
#   Time: 7.0, Action: DCPActionDir.LC_RIGHT, Cost: -2.983388668528007
#   Time: 8.0, Action: DCPActionDir.LK, Cost: -4.480845810931103
#   Time: 9.0, Action: DCPActionDir.LK, Cost: -6.05970625592443
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -7.7395920911208265
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -9.493973075350542
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -11.298653926110338
#
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (0.13253251359794227, 4.0, <DCPActionDir.LK: 0>)
# (-1.1892178347388658, 5.0, <DCPActionDir.LK: 0>)
# (-2.567831288225115, 6.0, <DCPActionDir.LK: 0>)
# (-4.002463655328672, 7.0, <DCPActionDir.LK: 0>)
# (-5.492335675939239, 8.0, <DCPActionDir.LK: 0>)
# (-7.049022480799899, 9.0, <DCPActionDir.LK: 0>)
# (-8.714335286617107, 10.0, <DCPActionDir.LK: 0>)
# (-10.461006491298438, 11.0, <DCPActionDir.LK: 0>)
# (-12.263521580716064, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (0.13253251359794227, 4.0, <DCPActionDir.LK: 0>)
# (-1.1892178347388658, 5.0, <DCPActionDir.LK: 0>)
# (-7.619569464002426, 10.0, <DCPActionDir.LC_LEFT: -1>)
# (-9.451764724331992, 11.0, <DCPActionDir.LK: 0>)
# (-11.305884757416816, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (1.3965014826854096, 3.0, <DCPActionDir.LK: 0>)
# (0.13253251359794227, 4.0, <DCPActionDir.LK: 0>)
# (-1.1892178347388658, 5.0, <DCPActionDir.LK: 0>)
# (-7.619569464002426, 10.0, <DCPActionDir.LC_RIGHT: 1>)
# (-9.451764724331992, 11.0, <DCPActionDir.LK: 0>)
# (-11.305884757416816, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (-2.983388668528007, 7.0, <DCPActionDir.LC_LEFT: -1>)
# (-4.480845810931103, 8.0, <DCPActionDir.LK: 0>)
# (-6.05970625592443, 9.0, <DCPActionDir.LK: 0>)
# (-7.7395920911208265, 10.0, <DCPActionDir.LK: 0>)
# (-9.493973075350542, 11.0, <DCPActionDir.LK: 0>)
# (-11.298653926110338, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (4.516867469879519, 1.0, <DCPActionDir.LK: 0>)
# (2.6016856919313485, 2.0, <DCPActionDir.LK: 0>)
# (-2.983388668528007, 7.0, <DCPActionDir.LC_RIGHT: 1>)
# (-4.480845810931103, 8.0, <DCPActionDir.LK: 0>)
# (-6.05970625592443, 9.0, <DCPActionDir.LK: 0>)
# (-7.7395920911208265, 10.0, <DCPActionDir.LK: 0>)
# (-9.493973075350542, 11.0, <DCPActionDir.LK: 0>)
# (-11.298653926110338, 12.0, <DCPActionDir.LK: 0>)
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="df691272-90aa-4a73-8fad-6e95f8c46a51">Loading BokehJS ...</span>
#     </div>
#   <div id="aca52631-e3df-4193-8c14-0ffaa7c2d7cc" data-root-id="p9255" style="display: contents;"></div>

# %% [markdown]
# # case9_bad_case_slow_car

# %%
file_name = 'case9_bad_case_slow_car.json'
file = file_path + file_name
dcp_tree = pybind_dcp_tree.DCPTree()
root_node = pybind_dcp_tree.DCPTreeNodeData()
ego_info = pybind_ilqr.IDMCarInfo(0.0, 16, 0.2, 5.0)
root_node.obs_pos = dcp_tree_plot.read_json(file)
root_node.ego_pos = ego_info
dcp_tree.set_IDM_params(1.0, 3, 16.6, 22.22)
root_node.tree_trace.clear()
dcp_tree.update_tree(root_node)
dcp_tree.show()
all_paths = dcp_tree.get_all_path()
print("all paths size is: ")
print(len(all_paths))
sorted_paths = sorted(all_paths, key=lambda x: x[-1][0])
top_10_min_cost_paths = sorted_paths[:15]
for i, path in enumerate(top_10_min_cost_paths):
    print(f"Path {i+1} with last step cost {path[-1][0]}:")
    for step in path:
        print(f"  Time: {step[1]}, Action: {step[2]}, Cost: {step[0]}")
    print()
sequences = dcp_tree_plot.converted_sequences(top_10_min_cost_paths)
# pprint(sequences)
plot = dcp_tree_plot.plot_dcp_tree_node(sequences)
output_notebook()
p = dcp_tree_plot.plot_lane_and_objs(root_node.obs_pos, ego_info)
show(column(p, plot))
# Out:
# all paths size is:
# 15
# Path 1 with last step cost -15.753948024928734:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.253502567499699
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.38585926478304
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 2.4276990199492134
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.41007390937108834
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.6389993383146315
#   Time: 6.0, Action: DCPActionDir.LK, Cost: -3.6972461134924384
#   Time: 7.0, Action: DCPActionDir.LK, Cost: -5.749302979748441
#   Time: 8.0, Action: DCPActionDir.LK, Cost: -7.786329536331072
#   Time: 9.0, Action: DCPActionDir.LK, Cost: -9.804633101639379
#   Time: 10.0, Action: DCPActionDir.LK, Cost: -11.803999363540873
#   Time: 11.0, Action: DCPActionDir.LK, Cost: -13.786210157170474
#   Time: 12.0, Action: DCPActionDir.LK, Cost: -15.753948024928734
#
# Path 2 with last step cost -15.278144847244647:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 5.0, Action: DCPActionDir.LC_LEFT, Cost: -0.22463903496272764
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.278144847244647
#
# Path 3 with last step cost -15.278144847244647:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 5.0, Action: DCPActionDir.LC_RIGHT, Cost: -0.22463903496272764
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.278144847244647
#
# Path 4 with last step cost -15.272016152258605:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.253502567499699
#   Time: 6.0, Action: DCPActionDir.LC_LEFT, Cost: -2.2227556849886803
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.272016152258605
#
# Path 5 with last step cost -15.272016152258605:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.253502567499699
#   Time: 6.0, Action: DCPActionDir.LC_RIGHT, Cost: -2.2227556849886803
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.272016152258605
#
# Path 6 with last step cost -15.146677254957083:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.253502567499699
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.38585926478304
#   Time: 7.0, Action: DCPActionDir.LC_LEFT, Cost: -4.242668706238179
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.146677254957083
#
# Path 7 with last step cost -15.146677254957083:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.253502567499699
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.38585926478304
#   Time: 7.0, Action: DCPActionDir.LC_RIGHT, Cost: -4.242668706238179
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -15.146677254957083
#
# Path 8 with last step cost -14.95366709430206:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.253502567499699
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.38585926478304
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 2.4276990199492134
#   Time: 8.0, Action: DCPActionDir.LC_LEFT, Cost: -6.269174063265261
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -14.95366709430206
#
# Path 9 with last step cost -14.95366709430206:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.253502567499699
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.38585926478304
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 2.4276990199492134
#   Time: 8.0, Action: DCPActionDir.LC_RIGHT, Cost: -6.269174063265261
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -14.95366709430206
#
# Path 10 with last step cost -14.74102502300018:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.253502567499699
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.38585926478304
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 2.4276990199492134
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.41007390937108834
#   Time: 9.0, Action: DCPActionDir.LC_LEFT, Cost: -8.291359912257771
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -14.74102502300018
#
# Path 11 with last step cost -14.74102502300018:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.253502567499699
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.38585926478304
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 2.4276990199492134
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.41007390937108834
#   Time: 9.0, Action: DCPActionDir.LC_RIGHT, Cost: -8.291359912257771
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -14.74102502300018
#
# Path 12 with last step cost -14.546895794556578:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.253502567499699
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.38585926478304
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 2.4276990199492134
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.41007390937108834
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.6389993383146315
#   Time: 10.0, Action: DCPActionDir.LC_LEFT, Cost: -10.302610626201712
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -14.546895794556578
#
# Path 13 with last step cost -14.546895794556578:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.253502567499699
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.38585926478304
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 2.4276990199492134
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.41007390937108834
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.6389993383146315
#   Time: 10.0, Action: DCPActionDir.LC_RIGHT, Cost: -10.302610626201712
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -14.546895794556578
#
# Path 14 with last step cost -14.396593975676197:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.253502567499699
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.38585926478304
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 2.4276990199492134
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.41007390937108834
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.6389993383146315
#   Time: 6.0, Action: DCPActionDir.LK, Cost: -3.6972461134924384
#   Time: 11.0, Action: DCPActionDir.LC_LEFT, Cost: -12.299937947861913
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -14.396593975676197
#
# Path 15 with last step cost -14.396593975676197:
#   Time: 0.0, Action: DCPActionDir.LK, Cost: 0.0
#   Time: 1.0, Action: DCPActionDir.LK, Cost: 6.253502567499699
#   Time: 2.0, Action: DCPActionDir.LK, Cost: 4.38585926478304
#   Time: 3.0, Action: DCPActionDir.LK, Cost: 2.4276990199492134
#   Time: 4.0, Action: DCPActionDir.LK, Cost: 0.41007390937108834
#   Time: 5.0, Action: DCPActionDir.LK, Cost: -1.6389993383146315
#   Time: 6.0, Action: DCPActionDir.LK, Cost: -3.6972461134924384
#   Time: 11.0, Action: DCPActionDir.LC_RIGHT, Cost: -12.299937947861913
#   Time: 12.01, Action: DCPActionDir.LK, Cost: -14.396593975676197
#
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.253502567499699, 1.0, <DCPActionDir.LK: 0>)
# (4.38585926478304, 2.0, <DCPActionDir.LK: 0>)
# (2.4276990199492134, 3.0, <DCPActionDir.LK: 0>)
# (0.41007390937108834, 4.0, <DCPActionDir.LK: 0>)
# (-1.6389993383146315, 5.0, <DCPActionDir.LK: 0>)
# (-3.6972461134924384, 6.0, <DCPActionDir.LK: 0>)
# (-5.749302979748441, 7.0, <DCPActionDir.LK: 0>)
# (-7.786329536331072, 8.0, <DCPActionDir.LK: 0>)
# (-9.804633101639379, 9.0, <DCPActionDir.LK: 0>)
# (-11.803999363540873, 10.0, <DCPActionDir.LK: 0>)
# (-13.786210157170474, 11.0, <DCPActionDir.LK: 0>)
# (-15.753948024928734, 12.0, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (-0.22463903496272764, 5.0, <DCPActionDir.LC_LEFT: -1>)
# (-15.278144847244647, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (-0.22463903496272764, 5.0, <DCPActionDir.LC_RIGHT: 1>)
# (-15.278144847244647, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.253502567499699, 1.0, <DCPActionDir.LK: 0>)
# (-2.2227556849886803, 6.0, <DCPActionDir.LC_LEFT: -1>)
# (-15.272016152258605, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.253502567499699, 1.0, <DCPActionDir.LK: 0>)
# (-2.2227556849886803, 6.0, <DCPActionDir.LC_RIGHT: 1>)
# (-15.272016152258605, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.253502567499699, 1.0, <DCPActionDir.LK: 0>)
# (4.38585926478304, 2.0, <DCPActionDir.LK: 0>)
# (-4.242668706238179, 7.0, <DCPActionDir.LC_LEFT: -1>)
# (-15.146677254957083, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.253502567499699, 1.0, <DCPActionDir.LK: 0>)
# (4.38585926478304, 2.0, <DCPActionDir.LK: 0>)
# (-4.242668706238179, 7.0, <DCPActionDir.LC_RIGHT: 1>)
# (-15.146677254957083, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.253502567499699, 1.0, <DCPActionDir.LK: 0>)
# (4.38585926478304, 2.0, <DCPActionDir.LK: 0>)
# (2.4276990199492134, 3.0, <DCPActionDir.LK: 0>)
# (-6.269174063265261, 8.0, <DCPActionDir.LC_LEFT: -1>)
# (-14.95366709430206, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.253502567499699, 1.0, <DCPActionDir.LK: 0>)
# (4.38585926478304, 2.0, <DCPActionDir.LK: 0>)
# (2.4276990199492134, 3.0, <DCPActionDir.LK: 0>)
# (-6.269174063265261, 8.0, <DCPActionDir.LC_RIGHT: 1>)
# (-14.95366709430206, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.253502567499699, 1.0, <DCPActionDir.LK: 0>)
# (4.38585926478304, 2.0, <DCPActionDir.LK: 0>)
# (2.4276990199492134, 3.0, <DCPActionDir.LK: 0>)
# (0.41007390937108834, 4.0, <DCPActionDir.LK: 0>)
# (-8.291359912257771, 9.0, <DCPActionDir.LC_LEFT: -1>)
# (-14.74102502300018, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.253502567499699, 1.0, <DCPActionDir.LK: 0>)
# (4.38585926478304, 2.0, <DCPActionDir.LK: 0>)
# (2.4276990199492134, 3.0, <DCPActionDir.LK: 0>)
# (0.41007390937108834, 4.0, <DCPActionDir.LK: 0>)
# (-8.291359912257771, 9.0, <DCPActionDir.LC_RIGHT: 1>)
# (-14.74102502300018, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.253502567499699, 1.0, <DCPActionDir.LK: 0>)
# (4.38585926478304, 2.0, <DCPActionDir.LK: 0>)
# (2.4276990199492134, 3.0, <DCPActionDir.LK: 0>)
# (0.41007390937108834, 4.0, <DCPActionDir.LK: 0>)
# (-1.6389993383146315, 5.0, <DCPActionDir.LK: 0>)
# (-10.302610626201712, 10.0, <DCPActionDir.LC_LEFT: -1>)
# (-14.546895794556578, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.253502567499699, 1.0, <DCPActionDir.LK: 0>)
# (4.38585926478304, 2.0, <DCPActionDir.LK: 0>)
# (2.4276990199492134, 3.0, <DCPActionDir.LK: 0>)
# (0.41007390937108834, 4.0, <DCPActionDir.LK: 0>)
# (-1.6389993383146315, 5.0, <DCPActionDir.LK: 0>)
# (-10.302610626201712, 10.0, <DCPActionDir.LC_RIGHT: 1>)
# (-14.546895794556578, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.253502567499699, 1.0, <DCPActionDir.LK: 0>)
# (4.38585926478304, 2.0, <DCPActionDir.LK: 0>)
# (2.4276990199492134, 3.0, <DCPActionDir.LK: 0>)
# (0.41007390937108834, 4.0, <DCPActionDir.LK: 0>)
# (-1.6389993383146315, 5.0, <DCPActionDir.LK: 0>)
# (-3.6972461134924384, 6.0, <DCPActionDir.LK: 0>)
# (-12.299937947861913, 11.0, <DCPActionDir.LC_LEFT: -1>)
# (-14.396593975676197, 12.01, <DCPActionDir.LK: 0>)
# (0.0, 0.0, <DCPActionDir.LK: 0>)
# (6.253502567499699, 1.0, <DCPActionDir.LK: 0>)
# (4.38585926478304, 2.0, <DCPActionDir.LK: 0>)
# (2.4276990199492134, 3.0, <DCPActionDir.LK: 0>)
# (0.41007390937108834, 4.0, <DCPActionDir.LK: 0>)
# (-1.6389993383146315, 5.0, <DCPActionDir.LK: 0>)
# (-3.6972461134924384, 6.0, <DCPActionDir.LK: 0>)
# (-12.299937947861913, 11.0, <DCPActionDir.LC_RIGHT: 1>)
# (-14.396593975676197, 12.01, <DCPActionDir.LK: 0>)
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b45560ba-df45-42d7-adcd-f4bda62578f2">Loading BokehJS ...</span>
#     </div>
#   <div id="c6da6b70-60bf-46ad-ab1b-071b119ce5b9" data-root-id="p11021" style="display: contents;"></div>
