# %%
import sys
import numpy as np
sys.path.append('/home/SENSETIME/fengxiaotong/ws/xviz/common_math/algorithm/build/env_simulator')
sys.path.append('/home/SENSETIME/fengxiaotong/ws/xviz/common_math/algorithm/build/cilqr')
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
import pybind_ilqr

# %% [markdown]
# ## Vehicle Model Test

# %%
sys.path.append('/home/SENSETIME/fengxiaotong/ws/xviz/common_math/algorithm/cilqr')
import py_lib.cilqr_debug as py_lib

# %%
py_lib.vehicle_model_test()
# Out:
# output:  [5.159855000791895, 7.378618364840872, 20.1, 1.004]

# %%
py_lib.vehicle_model_kappa_test()
# Out:
# output:  [5.029053505505063, 7.4575171340584046, 20.1, 1.0802]

# %%
py_lib.vehicle_model_kappa_fuzzy_test()
# Out:
# output:  [5.027965809455498, 7.4556636946504184, 20.1, 1.0802]

# %%
py_lib.vehicle_model_kappa_diff_test()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ce3bc002-6062-45e1-937f-683793dce005">Loading BokehJS ...</span>
#     </div>
#   <div id="ce894035-8457-4348-ae5f-6a91eb45f352" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# ## Kappa Vehicle Model Thr Test

# %%
py_lib.check_kappa_thr_diff(1e-3)
# Out:
# theta_thr:  0.001
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ccdbbc37-90c7-4136-9d20-01237ef554e1">Loading BokehJS ...</span>
#     </div>
#   <div id="e1ab5255-5ff6-43c9-bc99-85dea47d8dc1" data-root-id="p1292" style="display: contents;"></div>

# %%
py_lib.check_kappa_thr_diff(1e-2)
# Out:
# theta_thr:  0.01
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="edc6708e-1b69-4710-b392-db5f73aa9cfd">Loading BokehJS ...</span>
#     </div>
#   <div id="fbd3ae30-87b2-4b93-98fc-9ea19e9b7969" data-root-id="p1460" style="display: contents;"></div>

# %%
py_lib.check_kappa_thr_diff(1e-1)
# Out:
# theta_thr:  0.1
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="bf5087bc-9d9e-450e-b8b4-2f48b3bc6b49">Loading BokehJS ...</span>
#     </div>
#   <div id="dc5ede28-0def-4ecb-8d93-fa35de4c19a2" data-root-id="p1642" style="display: contents;"></div>

# %% [markdown]
# ## ILQR Debug

# %%
import pybind_env_simulator
sys.path.append('/home/SENSETIME/fengxiaotong/ws/xviz/common_math/algorithm/env_simulator')
from py_lib import py_env_sim
from py_lib import cilqr_plot

# %%
motion = pybind_ilqr.LateralLongitudinalMotion()
point_init = pybind_ilqr.PlanningPoint()
point_init.position.x = 10.0
point_init.position.y = 4.0
point_init.theta = 0.02
point_init.velocity = 25.0
point_init.acceleration  = 0.5

path = str("/home/SENSETIME/fengxiaotong/ws/xviz/common_math/algorithm/env_simulator/data/curva_lanes_case_2.json")

motion.init(path,point_init)

motion.execute()

# plot 
env = motion.get_env()
planning_origin = motion.get_planning_origin()

pts = env.get_all_center_points()
obs = env.get_all_obstacle()
planning_init = {}

planning_init['x'] = planning_origin.position.x
planning_init['y'] = planning_origin.position.y
planning_init['theta'] = planning_origin.theta

trajs = motion.get_init_trajectory()
traj_list = []
for traj in trajs:
    pt = {}
    pt['x'] = traj.position.x
    pt['y'] = traj.position.y
    pt['theta'] = traj.theta
    traj_list.append(pt)

trajs_new = motion.get_new_trajectory()
traj_new_list = []
for traj in trajs_new:
    pt = {}
    pt['x'] = traj.position.x
    pt['y'] = traj.position.y
    pt['theta'] = traj.theta
    traj_new_list.append(pt)
math_points = trajs = motion.get_match_point()
cilqr_plot.plot_cilqr_env(pts,obs,planning_init,traj_list,traj_new_list,math_points)
# py_env_sim.plot_env(pts,obs)
# Out:
# ---- loading straight_case_1 case ----
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cae42c00-1daa-4247-af8f-73aab237dba6">Loading BokehJS ...</span>
#     </div>
#   <div id="ae4ffca3-dbb1-4bed-a9e7-485185e17e05" data-root-id="p1838" style="display: contents;"></div>
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d4292699-e650-41e6-b284-89a7fc430c52">Loading BokehJS ...</span>
#     </div>
# ...

# %%
traj_list
# Out:
# [{'x': 10.0, 'y': 4.0, 'theta': 0.02},
#  {'x': 15.008998033399553, 'y': 4.100193320133599, 'theta': 0.02},
#  {'x': 20.03799206693244, 'y': 4.200786613601064, 'theta': 0.02},
#  {'x': 25.086982100598657, 'y': 4.301779880402396, 'theta': 0.02},
#  {'x': 30.155968134398208, 'y': 4.403173120537595, 'theta': 0.02},
#  {'x': 35.24495016833109, 'y': 4.50496633400666, 'theta': 0.02},
#  {'x': 40.3539282023973, 'y': 4.607159520809592, 'theta': 0.02},
#  {'x': 45.48290223659684, 'y': 4.709752680946391, 'theta': 0.02},
#  {'x': 50.63187227092972, 'y': 4.812745814417056, 'theta': 0.02},
#  {'x': 55.80083830539593, 'y': 4.916138921221588, 'theta': 0.02},
#  {'x': 60.98980033999547, 'y': 5.019932001359987, 'theta': 0.02},
#  {'x': 66.19875837472834, 'y': 5.124125054832252, 'theta': 0.02},
#  {'x': 71.42771240959455, 'y': 5.228718081638384, 'theta': 0.02},
#  {'x': 76.67666244459409, 'y': 5.333711081778382, 'theta': 0.02},
#  {'x': 81.94560847972696, 'y': 5.439104055252248, 'theta': 0.02},
# ...

# %%
alphas = 1.1**(-np.arange(10)**2)

# %%
alphas
# Out:
# array([1.00000000e+00, 9.09090909e-01, 6.83013455e-01, 4.24097618e-01,
#        2.17629136e-01, 9.22959982e-02, 3.23491843e-02, 9.37040641e-03,
#        2.24320079e-03, 4.43805318e-04])
