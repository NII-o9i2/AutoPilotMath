# %%
import sys
import numpy as np
import os
current_directory = os.getcwd()
relative_path1 = '../build/env_simulator'
relative_path2 = '../build/cilqr'
file_path1 = os.path.join(current_directory, relative_path1)
file_path2 = os.path.join(current_directory, relative_path2)
sys.path.append(file_path1)
sys.path.append(file_path2)
import pybind_env_simulator

relative_path3 = '../env_simulator'
file_path3 = os.path.join(current_directory, relative_path3)
sys.path.append(file_path3)
from py_lib import py_env_sim
from py_lib import cilqr_plot
import pybind_ilqr
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %% [markdown]
# ## case 1

# %%
point_init = pybind_env_simulator.PlanningPoint()
point_init.position.x = 10.0
point_init.position.y = 4.0
point_init.theta = 0.02
point_init.velocity = 25.0
point_init.acceleration  = 0.5
path = str(current_directory)+str("/../env_simulator/data/init_traj_case_1.json")

motion = cilqr_plot.run_motion(path, point_init)

cilqr_plot.plot_init_trah_gen(motion)

# cilqr_plot.plot_init_traj_gen_failed_path(motion)

# cilqr_plot.plot_iter_stat_list(motion)
# Out:
# init_traj_gen success
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2872">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8f768bd2-b4c8-45b0-8720-51c6b9fe5744" data-root-id="1001"></div>

# %% [markdown]
# ## case 2

# %%
point_init = pybind_env_simulator.PlanningPoint()
point_init.position.x = 10.0
point_init.position.y = 4.0
point_init.theta = 0.02
point_init.velocity = 25.0
point_init.acceleration  = 0.5
path = str(current_directory)+str("/../env_simulator/data/init_traj_case_2.json")

motion = cilqr_plot.run_motion(path, point_init)

cilqr_plot.plot_init_trah_gen(motion)

# cilqr_plot.plot_init_traj_gen_failed_path(motion)

# cilqr_plot.plot_iter_stat_list(motion)
# Out:
# init_traj_gen success
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9203">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="bea244dc-90fd-430c-8f6a-3a0046b125c6" data-root-id="3426"></div>

# %% [markdown]
# ## case 3

# %%
point_init = pybind_env_simulator.PlanningPoint()
point_init.position.x = 10.0
point_init.position.y = 4.0
point_init.theta = 0.02
point_init.velocity = 25.0
point_init.acceleration  = 0.5
path = str(current_directory)+str("/../env_simulator/data/init_traj_case_3.json")

motion = cilqr_plot.run_motion(path, point_init)

cilqr_plot.plot_init_trah_gen(motion)

cilqr_plot.plot_init_traj_gen_failed_path(motion)

# # cilqr_plot.plot_iter_stat_list(motion)
# Out:
# init_traj_gen failed
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="16089">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1f4d4ef2-ccb9-4ffb-9a1f-444d6d50f470" data-root-id="10312"></div>
# failed_path_set size  81
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="19248">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="4c38a2e7-7065-4b83-b1bb-c423f6292667" data-root-id="17345"></div>

# %% [markdown]
# ## case 4

# %%
point_init = pybind_env_simulator.PlanningPoint()
point_init.position.x = 10.0
point_init.position.y = 4.0
point_init.theta = 0.02
point_init.velocity = 25.0
point_init.acceleration  = 0.5
point_init.omega  = -0.1
path = str(current_directory)+str("/../env_simulator/data/init_traj_case_4.json")

motion = cilqr_plot.run_motion(path, point_init)

cilqr_plot.plot_init_trah_gen(motion)

# cilqr_plot.plot_init_traj_gen_failed_path(motion)

# # cilqr_plot.plot_iter_stat_list(motion)
# Out:
# init_traj_gen success
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="28850">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="eade2f90-bae3-463b-ba56-b833ede61700" data-root-id="23073"></div>

# %% [markdown]
# ## case 5

# %%
point_init = pybind_env_simulator.PlanningPoint()
point_init.position.x = 10.0
point_init.position.y = 4.0
point_init.theta = 0.02
point_init.velocity = 20.0
point_init.acceleration  = 0.5
point_init.omega  = -0.1
path = str(current_directory)+str("/../env_simulator/data/init_traj_case_5.json")

motion = cilqr_plot.run_motion(path, point_init)

cilqr_plot.plot_init_trah_gen(motion)

# cilqr_plot.plot_init_traj_gen_failed_path(motion)

# # cilqr_plot.plot_iter_stat_list(motion)
# Out:
# init_traj_gen success
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="36523">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1e6ee992-40e8-4fb3-81cc-be283b546225" data-root-id="30746"></div>

# %% [markdown]
# ## case 6

# %%
point_init = pybind_env_simulator.PlanningPoint()
point_init.position.x = 10.0
point_init.position.y = 4.0
point_init.theta = 0.02
point_init.velocity = 25.0
point_init.acceleration  = 0.5
point_init.omega  = 0.0
path = str(current_directory)+str("/../env_simulator/data/init_traj_case_6.json")

motion = cilqr_plot.run_motion(path, point_init)

cilqr_plot.plot_init_trah_gen(motion)

# cilqr_plot.plot_init_traj_gen_failed_path(motion)

# # cilqr_plot.plot_iter_stat_list(motion)
# Out:
# init_traj_gen success
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="50492">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e4fdbaa5-9554-46dc-b80d-dc2e9924dd8a" data-root-id="38566"></div>

# %% [markdown]
# ## case 7

# %%
point_init = pybind_env_simulator.PlanningPoint()
point_init.position.x = 10.0
point_init.position.y = 4.0
point_init.theta = 0.02
point_init.velocity = 25.0
point_init.acceleration  = 0.5
point_init.omega  = 0
path = str(current_directory)+str("/../env_simulator/data/init_traj_case_7.json")

motion = cilqr_plot.run_motion(path, point_init)

cilqr_plot.plot_init_trah_gen(motion)

# cilqr_plot.plot_init_traj_gen_failed_path(motion)

# # cilqr_plot.plot_iter_stat_list(motion)
# Out:
# init_traj_gen success
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="73477">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="29ba7385-66f1-48ea-9139-9aa0ef7e72e0" data-root-id="53158"></div>

# %% [markdown]
# ## case 8

# %%
point_init = pybind_env_simulator.PlanningPoint()
point_init.position.x = 10.0
point_init.position.y = 4.0
point_init.theta = 0.02
point_init.velocity = 25.0
point_init.acceleration  = 0.5
point_init.omega  = 0
path = str(current_directory)+str("/../env_simulator/data/init_traj_case_8.json")

motion = cilqr_plot.run_motion(path, point_init)

cilqr_plot.plot_init_trah_gen(motion)

# cilqr_plot.plot_init_traj_gen_failed_path(motion)

# # cilqr_plot.plot_iter_stat_list(motion)
# Out:
# init_traj_gen success
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="107790">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="aea8d3d2-9246-4bb8-9243-41c901f0fd40" data-root-id="76834"></div>

# %% [markdown]
# ## case 9

# %%
point_init = pybind_env_simulator.PlanningPoint()
point_init.position.x = 10.0
point_init.position.y = 4.0
point_init.theta = 0
point_init.velocity = 25.0
point_init.acceleration  = 0.5
path = str(current_directory)+str("/../env_simulator/data/init_traj_case_9.json")

motion = cilqr_plot.run_motion(path, point_init)

cilqr_plot.plot_init_trah_gen(motion)

# cilqr_plot.plot_init_traj_gen_failed_path(motion)

# cilqr_plot.plot_iter_stat_list(motion)
# Out:
# init_traj_gen success
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="113777">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="af3950df-b48e-4f7a-a1fd-61237259da64" data-root-id="111906"></div>

# %% [markdown]
# ## case 10

# %%
point_init = pybind_env_simulator.PlanningPoint()
point_init.position.x = 10.0
point_init.position.y = 4.0
point_init.theta = 0
point_init.velocity = 25.0
point_init.acceleration  = 0.5
path = str(current_directory)+str("/../env_simulator/data/init_traj_case_10.json")

motion = cilqr_plot.run_motion(path, point_init)

cilqr_plot.plot_init_trah_gen(motion)

# cilqr_plot.plot_init_traj_gen_failed_path(motion)

# cilqr_plot.plot_iter_stat_list(motion)
# Out:
# init_traj_gen success
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="118211">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="af8c32e7-5053-4e13-bd04-b7f4477cbf23" data-root-id="116340"></div>

# %% [markdown]
# ## case11

# %%
point_init = pybind_env_simulator.PlanningPoint()
point_init.position.x = 10.0
point_init.position.y = 4.0
point_init.theta = 0.01
point_init.velocity = 22.22
point_init.acceleration  = 0.5
path = str(current_directory)+str("/../env_simulator/data/init_traj_case_11.json")

motion = cilqr_plot.run_motion(path, point_init)

cilqr_plot.plot_init_trah_gen(motion)

# cilqr_plot.plot_init_traj_gen_failed_path(motion)

# cilqr_plot.plot_iter_stat_list(motion)
# Out:
# init_traj_gen success
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="122724">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="65dda6da-f046-44ac-80ef-f0979a619f1b" data-root-id="120853"></div>

# %% [markdown]
# ## case12

# %%
point_init = pybind_env_simulator.PlanningPoint()
point_init.position.x = 10.0
point_init.position.y = 4.0
point_init.theta = 0
point_init.velocity = 16.67
point_init.acceleration  = 0
path = str(current_directory)+str("/../env_simulator/data/init_traj_case_12.json")

motion = cilqr_plot.run_motion(path, point_init)

cilqr_plot.plot_init_trah_gen(motion)

# cilqr_plot.plot_init_traj_gen_failed_path(motion)

# cilqr_plot.plot_iter_stat_list(motion)
# Out:
# init_traj_gen success
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="127150">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d92765cf-48f7-45a1-a411-30f3da180937" data-root-id="125445"></div>
