# %%
import sys

# %%
sys.path.append('/home/SENSETIME/chengren1/ws/gitlab.senseauto.com/common_math/build/jupyter_notebook')

# %%
import pybind_test

# %%
# wm_x= [ 0,
#  -2.43316,
#  -7.74198,
#  -26.9626,
#  -30.7752,
#  -35.987,
#  -42.0991,
#  -49.5649,
#  -57.0095,
#  -62.1044,
#  -67.2854,
#  -67.2854,
#  -71.7438,
#  -75.388,
#  -82.6277,
#  -90.6996,
#  -99.1671,
#  -106.264,
#  -111.995,
#  -118.592,
#  -123.857,
#  -128.659,
#  -130.598,
#  -130.598,
#  -135.11,
#  -139.39,
#  -159.405,
#  -159.405,
#  -162.071,
#  -162.071,
#  -162.551,
#  -162.551,
#  -164.191,
#  -164.191,
#  -179.133]
# wm_y = [ 0, 
#  4.37759,
#  14.0168,
#  49.1319,
#  56.1682,
#  65.867,
#  77.3446,
#  91.5019,
#  105.674,
#  115.428,
#  125.436,
#  125.436,
#  134.096,
#  141.23,
#  155.504,
#  171.607,
#  188.63,
#  202.981,
#  214.653,
#  228.139,
#  238.93,
#  248.833,
#  252.912,
#  252.912,
#  262.383,
#  271.435,
#  313.984,
#  313.984,
#  319.635,
#  319.635,
#  320.661,
#  320.661,
#  324.157,
#  324.157,
#  356.064,
# ]

# %%
len(wm_x)
# Out:
# 35

# %%
len(wm_y)
# Out:
# 35

# %%
wm2_x = [
    0
 -8.18051,
 -20.1023,
 -28.0147,
 -34.4205,
 -39.8015,
 -43.2029,
-43.2029,
-45.6359,
-50.9442,
-70.1633,
-73.9755,
-79.1868,
-85.2984,
-92.7636,
-100.207,
-105.302,
-110.483,
-110.483,
-114.941,
-118.584,
-125.823,
-133.895,
-142.361,
-149.458,
-155.188,
-161.785,
-167.048,
-171.85,
-173.789,
-173.789,
-178.3,
-182.581,
-202.594
]
wm2_y = [
    0,
 14.1213,
 34.9325,
 48.8146,
 60.1254,
 69.7079,
 75.8139,
 75.8139,
 80.1916,
 89.831,
 124.946,
 131.983,
 141.682,
 153.159,
 167.317,
 181.489,
 191.244,
 201.251,
 201.251,
 209.911,
 217.046,
 231.32,
 247.423,
 264.446,
 278.797,
 290.47,
 303.955,
 314.746,
 324.649,
 328.728,
 328.728,
 338.2,
 347.252,
 389.801,
]
wm_2_raw_x = [
     12801,
 12792.8,
 12780.9,
 12773,
 12766.6,
 12761.2,
 12757.8,
 12755.3,
 12750,
 12730.8,
 12727,
 12721.8,
 12715.7,
 12708.2,
 12700.8,
 12695.7,
 12690.5,
 12686,
 12682.4,
 12675.2,
 12667.1,
 12658.6,
 12651.5,
 12645.8,
 12639.2,
 12633.9,
 12629.1,
 12627.2,
 12622.7,
 12618.4,
 12598.4
]
wm_2_raw_y = [
    6131.14,
6145.26,
6166.07,
6179.95,
6191.26,
6200.85,
6206.95,
6211.33,
6220.97,
6256.08,
6263.12,
6272.82,
6284.3,
6298.46,
6312.63,
6322.38,
6332.39,
6341.05,
6348.18,
6362.46,
6378.56,
6395.58,
6409.94,
6421.61,
6435.09,
6445.88,
6455.79,
6459.87,
6469.34,
6478.39,
6520.94
]

# %%
wm_x_3 = [
    0,
-8.17967,
-20.1002,
-28.0118,
-34.4169,
-39.7974,
-43.1984,
-43.1984,
-45.6311,
-50.9389,
-70.1559,
-73.9677,
-79.1784,
-85.2893,
-92.7537,
-100.197,
-105.291,
-110.471,
-110.471,
-114.928,
-118.572,
-125.81,
-133.88,
-142.346,
-149.441,
-155.171,
-161.767,
-167.03,
-171.831,
-173.77,
-173.77,
-178.28,
-182.56,
-202.571
]
wm_y_3 = [
     0,
 14.1217,
 34.9335,
 48.8161,
 60.1272,
 69.7099,
 75.8162,
 75.8162,
 80.194,
 89.8336,
 124.95,
 131.987,
 141.686,
 153.164,
 167.322,
 181.494,
 191.249,
 201.257,
 201.257,
 209.917,
 217.052,
 231.326,
 247.43,
 264.453,
 278.805,
 290.478,
 303.963,
 314.755,
 324.658,
 328.737,
 328.737,
 338.209,
 347.261,
 389.811
]

# %%
points_list = []
# wrong data
# for i in range(len(wm2_x)):
#     points_list.append(pybind_test.Point2D(wm2_x[i],wm2_y[i]))
    
# for i in range(len(wm_2_raw_y)):
#     points_list.append(pybind_test.Point2D(wm_2_raw_x[i],wm_2_raw_y[i]))
for i in range(len(wm_x)):
    points_list.append(pybind_test.Point2D(wm_x[i],wm_y[i]))

# %%
# noise_std, const double &A0, const double &A1,
#  const double &A2, const double &A3, const double &B0,
#                 const double &B1, const double &B2, const double &B3,
#                 const int &point_size, const double& point_resolution
# noise_std = 0.1
# a0 = 0
# a1 = 1
# a2 = 0
# a3 = 0
# b0 = 1
# b1 = 0.2
# b2 = 0.05
# b3 = 0.001
# point_size = 20
# point_resolution = 2.0
# points_list = pybind_test.gen_random_points(noise_std,a0,a1,a2,a3,b0,b1,b2,b3,point_size, point_resolution)
# eigen_coef = pybind_test.poly_fit_eigen_python(points_list)
# osqp_coef = pybind_test.poly_fit_osqp_python(points_list)
# spline_points = pybind_test.poly_fit_spline_python(points_list)
spline_new_points = pybind_test.poly_fit_spline_new_python(points_list)
spline_new_points_curva = pybind_test.poly_fit_spline_new_python_get_curva(points_list)
spline_new_points_piece = pybind_test.poly_fit_spline_new_python_piece(points_list)
# Out:
# point size 16 accumulate_s front 0 accumulate_s back 213.13 accumulate_s size 16
# num seg :1
# knot s0
# knot s213.13
# SplineFittingGeneratorInput num_segments 1 knots front 0 knots back 213.13 knots size 2 vec_0 (-0.485821, 0.874058) kappa_0 0
# OsqpSolver::Solve, optimization status: 1,  number of iterations: 25,  run_time(ms): 0.029021
#  x_coeffs 0 : 4.9209e-10
#  x_coeffs 1 : -5.3377e-08
#  x_coeffs 2 : 2.80278e-06
#  x_coeffs 3 : 0.000111965
#  x_coeffs 4 : -0.485343
#  x_coeffs 5 : 3.37361e-07
#  y_coeffs 0 : 2.82637e-10
#  y_coeffs 1 : -3.08968e-08
#  y_coeffs 2 : 1.56258e-06
#  y_coeffs 3 : 6.08431e-05
#  y_coeffs 4 : 0.874352
#  y_coeffs 5 : 2.24011e-07
# point size 16 accumulate_s front 0 accumulate_s back 213.13 accumulate_s size 16
# num seg :1
# knot s0
# knot s213.13
# SplineFittingGeneratorInput num_segments 1 knots front 0 knots back 213.13 knots size 2 vec_0 (-0.485821, 0.874058) kappa_0 0
# ...

# %%
# eigen_coef

# %%
# osqp_coef

# %%
spline_new_points

# %%
x = []
y = []
y_eigen = []
y_osqp_c = []

for point in points_list:
    x.append(point.x)
    y.append(point.y)
    # y_eigen.append(eigen_coef[0] * point.x **3 + eigen_coef[1] * point.x **2 + eigen_coef[2] * point.x  + eigen_coef[3] )
    # y_osqp_c.append(osqp_coef[3] * point.x **3 + osqp_coef[2] * point.x **2 + osqp_coef[1] * point.x  + osqp_coef[0] )
    
x_spline = []
y_spline = []

# for point in spline_points:
#     x_spline.append(point.x)
#     y_spline.append(point.y)
    
x_spline_new = []
y_spline_new = []

for point in spline_new_points:
    x_spline_new.append(point.x)
    y_spline_new.append(point.y)

x_spline_new_seg_piece = []
y_spline_new_seg_piece = []
for points in spline_new_points_piece:
    x_spline_new = []
    y_spline_new = []
    for point in points:
        x_spline_new.append(point.x)
        y_spline_new.append(point.y)
    x_spline_new_seg_piece.append(x_spline_new)
    y_spline_new_seg_piece.append(y_spline_new)

# %%
# import osqp
# import numpy as np
# from scipy import sparse
# x_i_pow = []

# point_num = len(points_list)
# # print(x[0:point_num])
# # print(y[0:point_num])
# order = 3
# for x_tmp in x:
#     x_tmp_list = [1, x_tmp, x_tmp *x_tmp , x_tmp *x_tmp*x_tmp]
#     x_i_pow.append(x_tmp_list)


# p = [[0 for j in range(order + 1)] for i in range(order + 1)]

# for i in range(order + 1):
#     for j in range(order + 1):
#         sum_tmp = 0.0
#         for k in range(point_num):
#             sum_tmp = sum_tmp + x_i_pow[k][i] * x_i_pow[k][j]
#         p[i][j] = 2*sum_tmp
# # print("p is",p)
# q = []

# for i in range(order+1):
#     sum_tmp = 0.0
#     for k in range(point_num):
#         sum_tmp = sum_tmp - 2* y[k] * x_i_pow[k][i]
#     q.append(sum_tmp)
# # print('q is ', q)
        
# a = [[0,0,0,1]]

# # Define problem data
# P = sparse.csc_matrix(p)
# # print(P)
# q = np.array(q)
# A = sparse.csc_matrix(a)
# l = np.array([-100000])
# u = np.array([1000000])

# # # Create an OSQP object
# prob = osqp.OSQP()

# # # # # Setup workspace and change alpha parameter
# prob.setup(P, q, A, l, u, alpha=1.0)

# # # # # # Solve problem
# res = prob.solve()
# count = 1
# print(res.x)
# y_osqp = []
# for i in range(point_num):
#     y_osqp.append(res.x[0] + res.x[1] * x[i] + res.x[2] * x[i]**2  + res.x[3] * x[i] **3)
# #     print("y fit is ",res.x[0] + res.x[1] * x[i] + res.x[2] * x[i]**2  + res.x[3] * x[i] **3 )
# #     print("y raw is ", y[i])

# %%
import random
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import WheelZoomTool

point_num = len(points_list)

# generate some data (1-10 for x, random values for y)
# generate list of rgb hex colors in relation to y
colors = [f"#{255:02x}{int((value * 255) / 100):02x}{255:02x}" for value in y[0:point_num]]

# create new plot
p = figure(
    title="random curv points",
    sizing_mode="stretch_width",
    max_width=1000,
    height=500,
)


# add circle and line renderers
line = p.line(x[0:point_num], y[0:point_num], line_color="blue", line_width=1,legend_label="raw point")
circle = p.circle(x[0:point_num], y[0:point_num], fill_color="blue", line_color="blue", size=5,legend_label="raw point")
line_eigen = p.line(x[0:point_num], y_eigen[0:point_num], line_color="red", line_width=1,legend_label="eigen point")
circle_eigen = p.circle(x[0:point_num], y_eigen[0:point_num], fill_color="red", line_color="red", size=5,legend_label="eigen point")
line_osqp = p.line(x[0:point_num], y_osqp_c[0:point_num], line_color="green", line_width=1,legend_label="osqp point c")
circle_osqp = p.circle(x[0:point_num], y_osqp_c[0:point_num], fill_color="green", line_color="green", size=5,legend_label="osqp point c")
line_spline = p.line(x_spline, y_spline, line_color="orange", line_width=1,legend_label="spline point")
circle_spline = p.circle(x_spline, y_spline, fill_color="orange", line_color="orange", size=5,legend_label="spline point")
seg = len(x_spline_new_seg_piece)
color_map = ['#084594', '#2171b5', '#4292c6', '#6baed6', '#9ecae1', '#c6dbef', '#deebf7', '#f7fbff',"blue"]
for index in range(seg):
    print(index)
    line_spline_new = p.line(x_spline_new_seg_piece[index], y_spline_new_seg_piece[index], line_color=color_map[index], line_width=1,legend_label="spline new point"+ str(index))
    circle_spline_new = p.circle(x_spline_new_seg_piece[index], y_spline_new_seg_piece[index], fill_color=color_map[index], size=5,legend_label="spline new point"+ str(index))
line_spline_new = p.line(x_spline_new, y_spline_new, line_color=color_map[0], line_width=1,legend_label="spline new point")
circle_spline_new = p.circle(x_spline_new, y_spline_new, fill_color=color_map[0], size=5,legend_label="spline new point")


p.legend.click_policy = 'hide'
p.toolbar.active_scroll = p.select_one(WheelZoomTool)

output_notebook()
# show the results
show(p)
# Out:
# 0
# ...
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fd47fa5a-db90-46fe-9849-bcb9d487add8">Loading BokehJS ...</span>
#     </div>
#   <div id="ca12478f-b8a3-4814-9848-b7f8f08a5ad0" data-root-id="p1001" style="display: contents;"></div>

# %%
# create new plot
p = figure(
    title="curva points",
    max_width=1000,
    height=500,
)

# add circle and line renderers
x_index = [i for i in range(1, len(spline_new_points_curva)+1)]

line = p.circle(x_index, spline_new_points_curva, fill_color="blue",legend_label="curva")
show(p)
# Out:
#   <div id="a42a4c94-0466-4842-91e5-b9c8610681ce" data-root-id="p1149" style="display: contents;"></div>

# %%
print(points_list[0].x,points_list[0].y)
# Out:
# 0.0 0.0

# %%
print(points_list[1].x,points_list[1].y)
# Out:
# -2.43316 4.37759

# %%
print(points_list[2].x,points_list[2].y)
# Out:
# -7.74198 14.0168

# %%
raw_x= [ 3333.99,
3333.99,
3333.99,
3333.99,
3333.98,
3333.99,
3334.26,
3334.26,
3334.25,
3334.25,
3334.24,
3334.23,
3334.22,
3334.21,
3334.2,
3334.19,
3334.16,
3334.13,
3334.1,
3334.56,
3334.52,
3334.47,
3334.42]

raw_y = [ -3613.97,
-3614.47,
-3614.97,
-3615.47,
-3615.97,
-3616.47,
-3622.86,
-3623.36,
-3623.87,
-3624.37,
-3624.87,
-3625.37,
-3625.87,
-3626.37,
-3626.87,
-3627.37,
-3628.37,
-3629.37,
-3630.38,
-3640.72,
-3641.72,
-3643.23,
-3644.45
]

result_x= [ 3334.01
,3334.09
,3334.17
,3334.21
,3334.22
,3334.21
,3334.18
,3334.17
,3334.19
,3334.24
,3334.34
,3334.46
,3334.55
,3334.55
,3334.36
,3334.02
,3333.5
,3332.77
,3331.85
,3330.76
,3329.5
,3328.1
,3326.55
,3324.88
,3323.12
,3321.26
,3319.34
,3317.37
,3315.38
,3313.38
,3311.39
,3309.45
,3307.55
,3305.73
,3304.01
,3302.4
,3300.92
,3299.58
,3298.39
,3297.38
,3296.55
,3295.91
,3295.46
,3295.21
,3295.17
,3295.33
,3295.69
,3296.25
,3297
,3297.93
,3299.04
,3300.32
,3301.74
,3303.3
,3304.98
,3306.75
,3308.62
,3310.54
,3312.52
,3314.51
,3316.51
,3318.49
,3320.44
,3322.32
,3324.13
,3325.84
,3327.44
,3328.91
,3330.23
,3331.4
,3332.39
,3333.2
,3333.82
,3334.25
,3334.47
,3334.5
,3334.32
,3333.93
,3333.35
,3332.58
,3331.63
,3330.5
,3329.21
,3327.77
,3326.2
,3324.51
,3322.72
,3320.85
,3318.92
,3316.94
,3314.95
,3312.95
,3310.97
,3309.03
,3307.15
,3305.35
,3303.65
,3302.07
,3300.61
,3299.31
,3298.16
,3297.19
,3296.4
,3295.79
,3295.39
,3295.19]

result_y = [ -3616.4747
,-3618.47
,-3620.46
,-3622.46
,-3624.46
,-3626.46
,-3628.46
,-3630.46
,-3632.46
,-3634.46
,-3636.45
,-3638.45
,-3640.45
,-3642.45
,-3644.45
,-3646.42
,-3648.35
,-3650.21
,-3651.99
,-3653.66
,-3655.22
,-3656.64
,-3657.91
,-3659.02
,-3659.95
,-3660.7
,-3661.26
,-3661.61
,-3661.77
,-3661.72
,-3661.48
,-3661.03
,-3660.38
,-3659.55
,-3658.53
,-3657.35
,-3656.01
,-3654.52
,-3652.91
,-3651.18
,-3649.36
,-3647.47
,-3645.52
,-3643.54
,-3641.54
,-3639.54
,-3637.58
,-3635.66
,-3633.8
,-3632.03
,-3630.37
,-3628.83
,-3627.42
,-3626.17
,-3625.08
,-3624.17
,-3623.44
,-3622.9
,-3622.57
,-3622.43
,-3622.5
,-3622.77
,-3623.24
,-3623.91
,-3624.76
,-3625.79
,-3627
,-3628.35
,-3629.85
,-3631.48
,-3633.22
,-3635.04
,-3636.95
,-3638.9
,-3640.89
,-3642.89
,-3644.88
,-3646.84
,-3648.76
,-3650.6
,-3652.36
,-3654.01
,-3655.54
,-3656.93
,-3658.17
,-3659.24
,-3660.13
,-3660.84
,-3661.35
,-3661.67
,-3661.78
,-3661.69
,-3661.39
,-3660.9
,-3660.22
,-3659.34
,-3658.29
,-3657.07
,-3655.7
,-3654.18
,-3652.54
,-3650.8
,-3648.96
,-3647.05
,-3645.09
,-3643.11
]

# %%
points_list = []
for i in range(len(raw_x)):
    points_list.append(pybind_test.Point2D(raw_x[i],raw_y[i]))

# %%
spline_new_points = pybind_test.poly_fit_spline_new_python(points_list)
spline_new_points_curva = pybind_test.poly_fit_spline_new_python_get_curva(points_list)
spline_new_points_piece = pybind_test.poly_fit_spline_new_python_piece(points_list)
# Out:
# point size 15 accumulate_s front 0 accumulate_s back 30.5005 accumulate_s size 15
# num seg :1
# knot s0
# knot s30.5005
# SplineFittingGeneratorInput num_segments 1 knots front 0 knots back 30.5005 knots size 2 vec_0 (0, -1) kappa_0 -0.00739271
# OsqpSolver::Solve, optimization status: 1,  number of iterations: 25,  run_time(ms): 0.794595
#  x_coeffs 0 : -0.000197729
#  x_coeffs 1 : 0.00278917
#  x_coeffs 2 : -0.0162869
#  x_coeffs 3 : 0.0457752
#  x_coeffs 4 : -0.0311465
#  x_coeffs 5 : 3333.99
#  y_coeffs 0 : -1.78528e-06
#  y_coeffs 1 : 2.57853e-05
#  y_coeffs 2 : -0.00015465
#  y_coeffs 3 : 0.000468631
#  y_coeffs 4 : -1.00011
#  y_coeffs 5 : -3613.97
# point size 15 accumulate_s front 0 accumulate_s back 30.5005 accumulate_s size 15
# num seg :1
# knot s0
# knot s30.5005
# SplineFittingGeneratorInput num_segments 1 knots front 0 knots back 30.5005 knots size 2 vec_0 (0, -1) kappa_0 -0.00739271
# ...

# %%
x_spline_new = []
y_spline_new = []

for point in spline_new_points:
    x_spline_new.append(point.x)
    y_spline_new.append(point.y)

x_spline_new_seg_piece = []
y_spline_new_seg_piece = []
for points in spline_new_points_piece:
    x_spline_new = []
    y_spline_new = []
    for point in points:
        x_spline_new.append(point.x)
        y_spline_new.append(point.y)
    x_spline_new_seg_piece.append(x_spline_new)
    y_spline_new_seg_piece.append(y_spline_new)

# %%
import random
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import WheelZoomTool

point_num = len(points_list)

# generate some data (1-10 for x, random values for y)
# generate list of rgb hex colors in relation to y
colors = [f"#{255:02x}{int((value * 255) / 100):02x}{255:02x}" for value in y[0:point_num]]

# create new plot
p = figure(
    title="random curv points",
    sizing_mode="stretch_width",
    max_width=1000,
    height=800,
)


# add circle and line renderers
line = p.line(raw_x[0:point_num], raw_y[0:point_num], line_color="green", line_width=1,legend_label="raw point")
circle = p.circle(raw_x[0:point_num], raw_y[0:point_num], fill_color="green", line_color="green", size=5,legend_label="raw point")

p.line(result_x[0:point_num], result_y[0:point_num], line_color="red", line_width=1,legend_label="online result point")
p.circle(result_x[0:point_num], result_y[0:point_num], fill_color="red", line_color="red", size=5,legend_label="online result point")

seg = len(x_spline_new_seg_piece)
color_map = ['#084594', '#2171b5', '#4292c6', '#6baed6', '#9ecae1', '#c6dbef', '#deebf7', '#f7fbff',"blue"]
for index in range(seg):
    print(index)
    line_spline_new = p.line(x_spline_new_seg_piece[index], y_spline_new_seg_piece[index], line_color=color_map[index], line_width=1,legend_label="spline new point"+ str(index))
    circle_spline_new = p.circle(x_spline_new_seg_piece[index], y_spline_new_seg_piece[index], fill_color=color_map[index], size=5,legend_label="spline new point"+ str(index))
line_spline_new = p.line(x_spline_new, y_spline_new, line_color=color_map[0], line_width=1,legend_label="spline new point")
circle_spline_new = p.circle(x_spline_new, y_spline_new, fill_color=color_map[0], size=5,legend_label="spline new point")


p.legend.click_policy = 'hide'
p.toolbar.active_scroll = p.select_one(WheelZoomTool)

output_notebook()
# show the results
show(p)
# Out:
# 0
# ...
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e1495251-d7b0-45ba-8433-b43d57f4612e">Loading BokehJS ...</span>
#     </div>
#   <div id="fa03981b-6c59-4fa7-8b29-96b47c561f4d" data-root-id="p1997" style="display: contents;"></div>
